# %% [markdown]
# # Analysis of American Economy 2000-2020

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns
#in order to see the entire dataframe we change the option set
pd.set_option('display.max_rows', None, 'display.max_columns', None)

# %% [markdown]
# We create a directory for the Graphs. In order to do so we must import the library os.

# %%
import os
# if the path allready exists the do not make the directory
if os.path.exists('Graphs')==False :
    os.mkdir('Graphs')

# %% [markdown]
# First we import the indexes that we have obltained so as to begin the analysis.
#
# This analysis will exclude the crisis period from 2007-12 to 2009-06. This period will be shown as a grey area in all the graphs.

# %% [markdown]
# ## Money Index
#
# ### Money Supply

# %%
M1=pd.read_csv('M1.csv',parse_dates=['DATE'],index_col='DATE')
M1.head()
# Out:
#                M1
# DATE
# 1975-01-06  273.4
# 1975-01-13  273.7
# 1975-01-20  273.8
# 1975-01-27  273.7
# 1975-02-03  275.2

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(M1['2000':],'b',label='M1')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Week)', ylabel='Billions of $',
       title='M1 Money Stock')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\M1_Money_Stock.png',bbox_inches='tight')

# %%
M2=pd.read_csv('M2.csv',parse_dates=['DATE'],index_col='DATE')
M2.head()
# Out:
#                 M2
# DATE
# 1980-11-03  1591.4
# 1980-11-10  1592.9
# 1980-11-17  1596.3
# 1980-11-24  1597.2
# 1980-12-01  1596.1

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(M2['2000':],'b',label='M2')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Week)', ylabel='Billions of $',
       title='M2 Money Stock')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\M2_Money_Stock.png',bbox_inches='tight')

# %%
MZM=pd.read_csv('MZM.csv',parse_dates=['DATE'],index_col='DATE')
MZM.head()
# Out:
#               MZM
# DATE
# 1980-11-03  906.8
# 1980-11-10  905.7
# 1980-11-17  902.7
# 1980-11-24  899.5
# 1980-12-01  896.2

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(MZM['2000':],'b',label='M1')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Week)', ylabel='Billions of $',
       title='MZM Money Stock')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\MZM_Money_Stock.png',bbox_inches='tight')

# %% [markdown]
# Plot the money supply

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(M1['2000':],'b',label='M1')
ax.plot(M2['2000':],'g',label='M2')
ax.plot(MZM['2000':],'r',label='MZM')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Week)', ylabel='Billions of $',
       title='Money Stock')
#insert a legend
ax.legend(loc='best')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Money_Stock.png',bbox_inches='tight')

# %%
M2_MON=M2.M2['2000':].resample('M').mean()
M2_MON.head()
# Out:
# DATE
# 2000-01-31    4661.040
# 2000-02-29    4668.650
# 2000-03-31    4694.975
# 2000-04-30    4751.875
# 2000-05-31    4744.140
# Freq: M, Name: M2, dtype: float64

# %%
MZM_MON=MZM.MZM['2000':].resample('M').mean()
MZM_MON.head()
# Out:
# DATE
# 2000-01-31    4384.280
# 2000-02-29    4383.950
# 2000-03-31    4418.850
# 2000-04-30    4472.925
# 2000-05-31    4465.560
# Freq: M, Name: MZM, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(M2_MON,'g',label='M2')
ax.plot(MZM_MON,'r',label='MZM')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Week)', ylabel='Billions of $',
       title='M2 - MZM Money Stock Monthly Average')
#insert a legend
ax.legend(loc='best')
fig.savefig('Graphs\M2_MZM_Money_Stock_Mon_Avg.png',bbox_inches='tight')

# %%
M2_log=np.log(M2_MON)
M2_log.head()
# Out:
# DATE
# 2000-01-31    8.446994
# 2000-02-29    8.448625
# 2000-03-31    8.454248
# 2000-04-30    8.466295
# 2000-05-31    8.464665
# Freq: M, Name: M2, dtype: float64

# %%
MZM_log=np.log(MZM_MON)
MZM_log.head()
# Out:
# DATE
# 2000-01-31    8.385781
# 2000-02-29    8.385705
# 2000-03-31    8.393635
# 2000-04-30    8.405798
# 2000-05-31    8.404150
# Freq: M, Name: MZM, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(M2_log,'g',label='M2')
ax.plot(MZM_log,'r',label='MZM')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Week)', ylabel='Log Billions of $',
       title='Log M2 - MZM Money Stock')
#insert a legend
ax.legend(loc='best')
fig.savefig('Graphs\M2_MZM_Money_Stock_Norm.png',bbox_inches='tight')

# %% [markdown]
# ### Money Velocities

# %%
M1V=pd.read_csv('M1V.csv',parse_dates=['DATE'],index_col='DATE')
M1V.head()
# Out:
#               M1V
# DATE
# 1959-01-01  3.662
# 1959-04-01  3.719
# 1959-07-01  3.709
# 1959-10-01  3.769
# 1960-01-01  3.878

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(M1V['2000':],'b',label='M1V')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Quarters)', ylabel='Ratio',
       title='Velocity of M1 Money Stock')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Velocity_of_M1_Money.png',bbox_inches='tight')

# %%
M2V=pd.read_csv('M2V.csv',parse_dates=['DATE'],index_col='DATE')
M2V.head()
# Out:
#               M2V
# DATE
# 1959-01-01  1.773
# 1959-04-01  1.789
# 1959-07-01  1.773
# 1959-10-01  1.779
# 1960-01-01  1.817

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(M2V['2000':],'b',label='M2V')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Quarters)', ylabel='Ratio',
       title='Velocity of M2 Money Stock')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Velocity_of_M2_Money.png',bbox_inches='tight')

# %%
MZMV=pd.read_csv('MZMV.csv',parse_dates=['DATE'],index_col='DATE')
MZMV.head()
# Out:
#              MZMV
# DATE
# 1959-01-01  1.848
# 1959-04-01  1.867
# 1959-07-01  1.849
# 1959-10-01  1.853
# 1960-01-01  1.889

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(MZMV['2000':],'b',label='MZMV')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Quarters)', ylabel='Ratio',
       title='Velocity of MZM Money Stock')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Velocity_of_MZM_Money.png',bbox_inches='tight')

# %% [markdown]
# Plot all money velocities in one graph

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(M1V['2000':],'b',label='M1V')
ax.plot(M2V['2000':],'r',label='M2V')
ax.plot(MZMV['2000':],'g',label='MZMV')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Quarters)', ylabel='Ratio',
       title='Velocities of all Money Stock')
#insert a legend
ax.legend(loc='best')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Velocity_of_Money.png',bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(M2V['2000':],'r',label='M2V')
ax.plot(MZMV['2000':],'g',label='MZMV')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Quarters)', ylabel='Ratio',
       title='Velocities of M2 & MZM Money Stock')
#insert a legend
ax.legend(loc='best')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Velocity_of_M2_MZM_Money.png',bbox_inches='tight')

# %% [markdown]
# Create a single dataframe drom M2 and MZM Money Stock Dataframes with the merge function.
#
# Merge is only for 2 dataframes

# %%
VMONST=pd.merge(M2V,MZMV,on='DATE', how='outer', indicator=True)
VMONST.head()
# Out:
#               M2V   MZMV _merge
# DATE
# 1959-01-01  1.773  1.848   both
# 1959-04-01  1.789  1.867   both
# 1959-07-01  1.773  1.849   both
# 1959-10-01  1.779  1.853   both
# 1960-01-01  1.817  1.889   both

# %% [markdown]
# Create a single datraframe with all the Money Stock Values with concat function

# %%
VMONSTA=pd.concat([M1V['1980-11-03':],M2V.M2V,MZMV.MZMV],axis=1)
VMONSTA.head()
# Out:
#             M1V    M2V   MZMV
# DATE
# 1959-01-01  NaN  1.773  1.848
# 1959-04-01  NaN  1.789  1.867
# 1959-07-01  NaN  1.773  1.849
# 1959-10-01  NaN  1.779  1.853
# 1960-01-01  NaN  1.817  1.889

# %%
fig, ax = plt.subplots(nrows=2,ncols=1,figsize = (15,10))
ax[0].plot(M2['2000':],'g',label='M2')
ax[0].plot(MZM['2000':],'r',label='MZM')
ax[0].axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax[0].set(xlabel='time (Week)', ylabel='Billions of $',
       title='M2 - MZM Money Stock')
#insert a legend
ax[0].legend(loc='best')
#introduce grid on the plot
ax[0].grid()
ax[1].plot(M2V['2000':]['2000':],'g',label='M2V')
ax[1].plot(MZMV['2000':],'r',label='MZMV')
# define the axes properties and the title of the graph
ax[1].set(xlabel='time (Quarters)', ylabel='Ratio',
       title='Velocities of M2 & MZM Money Stock')
#insert a legend
ax[1].legend(loc='best')
#introduce grid on the plot
ax[1].axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
ax[1].grid()
#Save the plot
fig.savefig('Graphs\M2_MZM_Money_Stock_V.png',bbox_inches='tight')

# %% [markdown]
# ### Money Multiplier

# %% [markdown]
# NOTICE:
# The money multiplier stops at the end of 2019

# %%
MULT=pd.read_csv('MULT.csv',parse_dates=['DATE'],index_col='DATE')
MULT.head()
# Out:
#              MULT
# DATE
# 1984-02-15  2.876
# 1984-02-29  2.886
# 1984-03-14  2.866
# 1984-03-28  2.883
# 1984-04-11  2.869

# %%
MULT.tail()
# Out:
#              MULT
# DATE
# 2019-10-09  1.186
# 2019-10-23  1.212
# 2019-11-06  1.201
# 2019-11-20  1.194
# 2019-12-04  1.197

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot( MULT['2000':],'b',label='MULT')
# draw a grey bar in order to show the crisis period. 
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (14 days)', ylabel='Ratio',
       title='M1 Money Multiplier')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\M1_Money_Multiplier.jpg',optimize=True,bbox_inches='tight')

# %% [markdown]
# in order to find the mean value of every month we will use the resample function with frequency ="M"=month nad the nimpy function "mean"

# %%
MULT_MON=MULT['MULT']['2000':].resample('M').mean() 
MULT_MON.head()
# Out:
# DATE
# 2000-01-31    1.826000
# 2000-02-29    1.842500
# 2000-03-31    1.842500
# 2000-04-30    1.856500
# 2000-05-31    1.829667
# Freq: M, Name: MULT, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot( MULT_MON,'b',label='MULT')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Ratio',
       title='M1 Money Multiplier Monthly Average')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\M1_Money_Multiplier_Mon_Avg.jpg',optimize=True,bbox_inches='tight')

# %% [markdown]
# ## Consumers

# %% [markdown]
# ### Consumer Price Index

# %%
CPALT=pd.read_csv('CPALTT01USQ657N.csv',parse_dates=['DATE'],index_col='DATE')
CPALT.head()
# Out:
#             CPALTT01USQ657N
# DATE
# 1960-01-01        -0.113379
# 1960-04-01         0.567537
# 1960-07-01         0.225734
# 1960-10-01         0.675676
# 1961-01-01         0.000000

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot( CPALT['2000':],'b',label='MULT')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Quarters)', ylabel='Growth Rate Previous Period',
       title='Consumer Price Index: Total All Items for the United States')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Consumer_Price_Index.png',bbox_inches='tight')

# %% [markdown]
# ### Consumer Price Index for All Urban Consumers

# %%
CPIL=pd.read_csv('CPILFESL.csv',parse_dates=['DATE'],index_col='DATE')
CPIL.head()
# Out:
#             CPILFESL
# DATE
# 1957-01-01      28.5
# 1957-02-01      28.6
# 1957-03-01      28.7
# 1957-04-01      28.8
# 1957-05-01      28.8

# %%
CPIL_MON=CPIL['CPILFESL']['2000':].resample('M').mean()/100 
CPIL_MON.head()
# Out:
# DATE
# 2000-01-31    1.793
# 2000-02-29    1.794
# 2000-03-31    1.800
# 2000-04-30    1.803
# 2000-05-31    1.807
# Freq: M, Name: CPILFESL, dtype: float64

# %%
CPIL_MON=CPIL_MON.shift(-1)
CPIL_MON.dropna(axis=0,inplace=True)
CPIL_MON.head()
# Out:
# DATE
# 2000-01-31    1.794
# 2000-02-29    1.800
# 2000-03-31    1.803
# 2000-04-30    1.807
# 2000-05-31    1.811
# Freq: M, Name: CPILFESL, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot( CPIL_MON,'b',label='CPILCPIL')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (months)', ylabel='Index 1982:1984=100',
       title='Consumer Price Index for All Urban Consumers: All Items Less Food and Energy in U.S. City Average')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Consumer_Price_Index_All.png',bbox_inches='tight')

# %% [markdown]
# ### Harmonized Index of Consumer Prices

# %%
CPUSM=pd.read_csv('CP0000USM086NEST.csv',parse_dates=['DATE'],index_col='DATE')
# rename the column of the newly created series
CPUSM.rename({'CP0000USM086NEST':'CPUSM'},axis=1,inplace=True)
CPUSM.head()
# Out:
#             CPUSM
# DATE
# 2001-12-01  74.09
# 2002-01-01  74.22
# 2002-02-01  74.39
# 2002-03-01  74.83
# 2002-04-01  75.34

# %%
CPUSM_MON=CPUSM.resample('M').mean()
CPUSM_MON.head()
# Out:
#             CPUSM
# DATE
# 2001-12-31  74.09
# 2002-01-31  74.22
# 2002-02-28  74.39
# 2002-03-31  74.83
# 2002-04-30  75.34

# %%
CPUSM_MON=CPUSM_MON.shift(-1)
CPUSM_MON.dropna(axis=0,inplace=True)
CPUSM_MON.head()
# Out:
#             CPUSM
# DATE
# 2001-12-31  74.22
# 2002-01-31  74.39
# 2002-02-28  74.83
# 2002-03-31  75.34
# 2002-04-30  75.30

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(CPUSM_MON,'b',label='CPUSM')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Index 2015=100',
       title='Harmonized Index of Consumer Prices')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Consumer_Price.png',bbox_inches='tight')

# %% [markdown]
# ### Consumer Opinion Surveys: Confidence Indicators: Composite Indicators: OECD Indicator for the United States

# %%
CSCICP=pd.read_csv('CSCICP03USM665S.csv',parse_dates=['DATE'],index_col='DATE')
CSCICP.rename({'CSCICP03USM665S':'CSCICP'},axis=1,inplace=True)
CSCICP.head()
# Out:
#                 CSCICP
# DATE
# 1960-01-01  101.473921
# 1960-02-01  101.222112
# 1960-03-01  101.004571
# 1960-04-01  100.884572
# 1960-05-01  100.914868

# %%
CSCICP_MON=CSCICP['2000':].resample('M').mean()/100
CSCICP_MON.head()
# Out:
#               CSCICP
# DATE
# 2000-01-31  1.026100
# 2000-02-29  1.026613
# 2000-03-31  1.025828
# 2000-04-30  1.025648
# 2000-05-31  1.025403

# %%
CSCICP_MON=CSCICP_MON.shift(-1)
CSCICP_MON.dropna(axis=0,inplace=True)
CSCICP_MON.head()
# Out:
#               CSCICP
# DATE
# 2000-01-31  1.026613
# 2000-02-29  1.025828
# 2000-03-31  1.025648
# 2000-04-30  1.025403
# 2000-05-31  1.024444

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(CSCICP_MON,'b',label='CSCICP')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Normalized (Normal=100)',
       title='Consumer Opinion Surveys: Confidence Indicators: ')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Consumer_Opinion_Surveys.png',bbox_inches='tight')

# %% [markdown]
# ### Inflation, consumer prices for the United States

# %%
INF=pd.read_csv('FPCPITOTLZGUSA.csv',parse_dates=['DATE'],index_col='DATE')
INF.head()
# Out:
#             FPCPITOTLZGUSA
# DATE
# 1960-01-01        1.457976
# 1961-01-01        1.070724
# 1962-01-01        1.198773
# 1963-01-01        1.239669
# 1964-01-01        1.278912

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(INF['2000':],'b',label='INF')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Year)', ylabel='Percent',
       title='Inflation, consumer prices for the United States')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Inflation.png',bbox_inches='tight')

# %% [markdown]
# ## Deposits

# %% [markdown]
# ### Excess Reserves of Depository Institutions

# %%
EXCSR=pd.read_csv('EXCSRESNS.csv',parse_dates=['DATE'],index_col='DATE')
EXCSR.head()
# Out:
#             EXCSRESNS
# DATE
# 1984-02-01     1606.0
# 1984-03-01      668.0
# 1984-04-01      474.0
# 1984-05-01      570.0
# 1984-06-01      759.0

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(EXCSR['2000':],'b',label='EXCSR')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Millinos of $',
       title='Excess Reserves of Depository Institutions')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Excess_Reserves_of_Depository.png',bbox_inches='tight')

# %%
EXCSR_MON=EXCSR.EXCSRESNS['2000':].resample('M').mean()/100
EXCSR_MON.head()
# Out:
# DATE
# 2000-01-31    20.14
# 2000-02-29    11.13
# 2000-03-31    12.08
# 2000-04-30    11.67
# 2000-05-31     9.70
# Freq: M, Name: EXCSRESNS, dtype: float64

# %%
EXCSR_MON=EXCSR_MON.shift(-1)
EXCSR_MON.dropna(axis=0,inplace=True)
EXCSR_MON.head()
# Out:
# DATE
# 2000-01-31    11.13
# 2000-02-29    12.08
# 2000-03-31    11.67
# 2000-04-30     9.70
# 2000-05-31    11.15
# Freq: M, Name: EXCSRESNS, dtype: float64

# %%
EXCSR_MON=EXCSR_MON.shift(-1)
EXCSR_MON.dropna(axis=0,inplace=True)
EXCSR_MON.head()
# Out:
# DATE
# 2000-01-31    12.08
# 2000-02-29    11.67
# 2000-03-31     9.70
# 2000-04-30    11.15
# 2000-05-31    11.43
# Freq: M, Name: EXCSRESNS, dtype: float64

# %%
EXCSR_log=np.log(EXCSR_MON)
EXCSR_log.head()
# Out:
# DATE
# 2000-01-31    2.491551
# 2000-02-29    2.457021
# 2000-03-31    2.272126
# 2000-04-30    2.411439
# 2000-05-31    2.436241
# Freq: M, Name: EXCSRESNS, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(EXCSR_log,'b',label='EXCSR')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Log Millions of $',
       title='Log Excess Reserves of Depository Institutions')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Excess_Reserves_of_Depository_Norm.png',bbox_inches='tight')

# %% [markdown]
# ### Total Savings Deposits at all Depository Institutions

# %%
WSAV=pd.read_csv('WSAVNS.csv',parse_dates=['DATE'],index_col='DATE')
WSAV.head()
# Out:
#             WSAVNS
# DATE
# 1975-01-06   135.9
# 1975-01-13   136.4
# 1975-01-20   136.5
# 1975-01-27   136.7
# 1975-02-03   136.9

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(WSAV['2000':],'b',label='WSAV')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Week)', ylabel='Billions of $',
       title='Total Savings Deposits at all Depository Institutions')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Total_Savings_Deposits.png',bbox_inches='tight')

# %%
WSAV_MON=WSAV['WSAVNS']['2000':].resample('M').mean()
WSAV_MON.head()
# Out:
# DATE
# 2000-01-31    1730.960
# 2000-02-29    1743.600
# 2000-03-31    1768.875
# 2000-04-30    1799.100
# 2000-05-31    1770.160
# Freq: M, Name: WSAVNS, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(WSAV_MON,'b',label='WSAV_MON')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Log Billions of $',
       title='Total Savings Deposits at all Depository Institutions Monthly Average')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Total_Savings_Deposits_Mon_Avg.png',bbox_inches='tight')

# %%
WSAV_log=np.log(WSAV_MON)
WSAV_log.head()
# Out:
# DATE
# 2000-01-31    7.456431
# 2000-02-29    7.463707
# 2000-03-31    7.478099
# 2000-04-30    7.495042
# 2000-05-31    7.478825
# Freq: M, Name: WSAVNS, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(WSAV_log,'b',label='WSAV_norm')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Log Billions of $',
       title='Log Total Savings Deposits at all Depository Institutions Monthly Average')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Total_Savings_Deposits_Mon_Avg_Norm.png',bbox_inches='tight')

# %% [markdown]
# ### Savings Deposits - Total

# %%
SAVE=pd.read_csv('SAVINGSL.csv',parse_dates=['DATE'],index_col='DATE')
SAVE.head()
# Out:
#             SAVINGSL
# DATE
# 1959-01-01     136.0
# 1959-02-01     136.6
# 1959-03-01     137.6
# 1959-04-01     138.4
# 1959-05-01     139.5

# %%
SAVE_MON=SAVE['2000':].resample('M').mean()
SAVE_MON.head()
# Out:
#             SAVINGSL
# DATE
# 2000-01-31    1741.6
# 2000-02-29    1751.4
# 2000-03-31    1761.6
# 2000-04-30    1779.5
# 2000-05-31    1776.9

# %%
SAVE_MON=SAVE_MON.shift(-1)
SAVE_MON.dropna(axis=0,inplace=True)
SAVE_MON.head()
# Out:
#             SAVINGSL
# DATE
# 2000-01-31    1751.4
# 2000-02-29    1761.6
# 2000-03-31    1779.5
# 2000-04-30    1776.9
# 2000-05-31    1786.4

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(SAVE_MON,'b',label='SAVE')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Billions of U.S. Dollars',
       title='Savings Deposits - Total ')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Savings_Deposits.png',bbox_inches='tight')

# %%
SAVE_log=np.log(SAVE_MON)
SAVE_log.head()
# Out:
#             SAVINGSL
# DATE
# 2000-01-31  7.468171
# 2000-02-29  7.473978
# 2000-03-31  7.484088
# 2000-04-30  7.482626
# 2000-05-31  7.487958

# %% [markdown]
# ## Interest Rates

# %% [markdown]
# ### Bank Prime Loan Rate
#
# For the DPRIME variable we can observe that we have missing values. The basic problem is that all data are represented as object and not float values

# %%
Dprime=pd.read_csv('DPRIME.csv',parse_dates=['DATE'],index_col='DATE')
Dprime.head()
# Out:
#            DPRIME
# DATE
# 1955-08-04   3.25
# 1955-08-05   3.25
# 1955-08-08   3.25
# 1955-08-09   3.25
# 1955-08-10   3.25

# %% [markdown]
# We replace the missing values which was represented as "." in the original Dataset with the np.NaN value

# %%
Drime=Dprime.replace(".",np.NaN)
Dprime.head()
# Out:
#            DPRIME
# DATE
# 1955-08-04   3.25
# 1955-08-05   3.25
# 1955-08-08   3.25
# 1955-08-09   3.25
# 1955-08-10   3.25

# %%
# check the type of the variables using the dtypes function
Dprime.dtypes
# Out:
# DPRIME    object
# dtype: object

# %% [markdown]
# We convert the string series to float values

# %%
Dprime ['DPRIME'] = pd.to_numeric(Dprime['DPRIME'], errors='coerce')
# check again to see if variables are the correct type
Dprime.dtypes
# Out:
# DPRIME    float64
# dtype: object

# %% [markdown]
# We the fill the NaN values with the previous values. This method considerd the optimal for this dataset because there is a contiouty in the values of the data

# %%
Dprime=Dprime.fillna(method='bfill')

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(Dprime['2000':],'b',label='DPRIME')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (day)', ylabel='Percent',
       title='Bank Prime Loan Rate')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Bank_Prime_Loan.png',bbox_inches='tight')

# %%
DPRIME_MON=Dprime['DPRIME']['2000':'2020-02'].resample('M').mean() 
DPRIME_MON.head()
# Out:
# DATE
# 2000-01-31    8.500000
# 2000-02-29    8.726190
# 2000-03-31    8.836957
# 2000-04-30    9.000000
# 2000-05-31    9.239130
# Freq: M, Name: DPRIME, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(DPRIME_MON,'b',label='DPRIME')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Percent',
       title='Bank Prime Loan Rate Monthly Average')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Bank_Prime_Loan.png',bbox_inches='tight')

# %% [markdown]
# ### Effective Federal Funds Rate

# %%
FED=pd.read_csv('FEDFUNDS.csv',parse_dates=['DATE'],index_col='DATE')
FED['2000':].head()
# Out:
#             FEDFUNDS
# DATE
# 2000-01-01      5.45
# 2000-02-01      5.73
# 2000-03-01      5.85
# 2000-04-01      6.02
# 2000-05-01      6.27

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(FED['2000':],'b',label='FED')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Percent',
       title='Effective Federal Funds Rate')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Effective_Federal_Funds_Rate_Mon_Avg.png',bbox_inches='tight')

# %%
FED_MON=FED.FEDFUNDS['2000':].resample('M').mean()
FED_MON.head()
# Out:
# DATE
# 2000-01-31    5.45
# 2000-02-29    5.73
# 2000-03-31    5.85
# 2000-04-30    6.02
# 2000-05-31    6.27
# Freq: M, Name: FEDFUNDS, dtype: float64

# %%
FED_MON=FED_MON.shift(-1)
FED_MON.dropna(axis=0,inplace=True)
FED_MON.head()
# Out:
# DATE
# 2000-01-31    5.73
# 2000-02-29    5.85
# 2000-03-31    6.02
# 2000-04-30    6.27
# 2000-05-31    6.53
# Freq: M, Name: FEDFUNDS, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(FED_MON,'b',label='FED')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Percent',
       title='Effective Federal Funds Rate')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Effective_Federal_Funds_Rate_Mon_Avg.png',bbox_inches='tight')

# %% [markdown]
# ### 10-Year Treasury Constant Maturity Minus 3-Month Treasury Constant Maturity
#
# This dataset has missing values

# %%
TYM=pd.read_csv('T10Y3M.csv',parse_dates=['DATE'],index_col='DATE')
# check the type of the variable
type(TYM.T10Y3M[0])
# Out:
# str

# %% [markdown]
# In order to fill the blank cells we will make use of the interpolation linear method

# %%
TYM=TYM.replace(".",np.NaN)
TYM ['T10Y3M'] = pd.to_numeric(TYM['T10Y3M'], errors='coerce')
TYM=TYM.interpolate(method='linear',axis=0)
TYM.head()
# Out:
#             T10Y3M
# DATE
# 1982-01-04    2.32
# 1982-01-05    2.24
# 1982-01-06    2.43
# 1982-01-07    2.46
# 1982-01-08    2.50

# %%
#check again to see if the variable is the correct type
type(TYM.T10Y3M[0])
# Out:
# numpy.float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(TYM['2000':],'b',label='TYM')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (day)', ylabel='Percent',
       title='10-Year Treasury Constant Maturity Minus 3-Month Treasury Constant Maturity')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Treasury_Constant_Maturity.png',bbox_inches='tight')

# %%
TYM_MON=TYM['T10Y3M']['2000':'2020-02'].resample('M').mean()/100
TYM_MON.head()
# Out:
# DATE
# 2000-01-31    0.011655
# 2000-02-29    0.007852
# 2000-03-31    0.003926
# 2000-04-30    0.001705
# 2000-05-31    0.004485
# Freq: M, Name: T10Y3M, dtype: float64

# %%
TYM_MON.tail()
# Out:
# DATE
# 2019-10-31    0.000309
# 2019-11-30    0.002424
# 2019-12-31    0.002986
# 2020-01-31    0.002137
# 2020-02-29   -0.000390
# Freq: M, Name: T10Y3M, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(TYM_MON,'b',label='TYM')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Percent',
       title='10-Year Treasury Constant Maturity Minus 3-Month Treasury Constant Maturity Monthly Average')
#introduce grid on the plot
ax.grid()
#show the plot
plt.show()
#Save the plot
fig.savefig('Graphs\Treasury_Constant_Maturity_Mon_Avg.png',bbox_inches='tight')

# %% [markdown]
# ## Loans

# %% [markdown]
# ### Consumer Loans, All Commercial Banks

# %%
CONS=pd.read_csv('CONSUMER.csv',parse_dates=['DATE'],index_col='DATE')
CONS.head()
# Out:
#             CONSUMER
# DATE
# 1947-01-01    4.1653
# 1947-02-01    4.2966
# 1947-03-01    4.4306
# 1947-04-01    4.5687
# 1947-05-01    4.7087

# %%
CONS_MON=CONS['2000':].resample('M').mean()
CONS_MON.head()
# Out:
#             CONSUMER
# DATE
# 2000-01-31  510.1748
# 2000-02-29  510.8263
# 2000-03-31  514.6795
# 2000-04-30  520.3064
# 2000-05-31  523.9815

# %%
CONS_MON=CONS_MON.shift(-1)
CONS_MON.dropna(axis=0,inplace=True)
CONS_MON.head()
# Out:
#             CONSUMER
# DATE
# 2000-01-31  510.8263
# 2000-02-29  514.6795
# 2000-03-31  520.3064
# 2000-04-30  523.9815
# 2000-05-31  529.5361

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(CONS_MON,'b',label='CONS')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Billions of U.S. Dollars',
       title='Consumer Loans, All Commercial Banks')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Consumer_Loans.png',bbox_inches='tight')

# %%
CONS_log=np.log(CONS_MON)
CONS_log.head()
# Out:
#             CONSUMER
# DATE
# 2000-01-31  6.236030
# 2000-02-29  6.243544
# 2000-03-31  6.254418
# 2000-04-30  6.261456
# 2000-05-31  6.272001

# %% [markdown]
# ### Real Estate Loans: Residential Real Estate Loans: Revolving Home Equity Loans, All Commercial Banks

# %%
REL=pd.read_csv('RHEACBW027SBOG.csv',parse_dates=['DATE'],index_col='DATE')
REL.rename(columns={'RHEACBW027SBOG':'RealEstLoans'},inplace=True)
REL.head()
# Out:
#             RealEstLoans
# DATE
# 1987-06-17       23.6385
# 1987-06-24       23.8900
# 1987-07-01       24.3287
# 1987-07-08       24.5814
# 1987-07-15       24.8796

# %%
REL_MON=REL['2000':].resample('M').mean()
REL_MON.head()
# Out:
#             RealEstLoans
# DATE
# 2000-01-31    104.830850
# 2000-02-29    106.347975
# 2000-03-31    108.324040
# 2000-04-30    111.137125
# 2000-05-31    113.378220

# %%
REL_MON=REL_MON.shift(-1)
REL_MON.dropna(axis=0,inplace=True)
REL_MON.head()
# Out:
#             RealEstLoans
# DATE
# 2000-01-31    106.347975
# 2000-02-29    108.324040
# 2000-03-31    111.137125
# 2000-04-30    113.378220
# 2000-05-31    114.386825

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(REL_MON,'b',label='REL')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Billions of U.S. Dollars',
       title='Real Estate Loans: Residential Real Estate Loans')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Real_Estate_Loans.png',bbox_inches='tight')

# %%
REL_log=np.log(REL_MON)
REL_log.head()
# Out:
#             RealEstLoans
# DATE
# 2000-01-31      4.666717
# 2000-02-29      4.685127
# 2000-03-31      4.710765
# 2000-04-30      4.730729
# 2000-05-31      4.739586

# %% [markdown]
# ### Commercial and Industrial Loans, All Commercial Banks

# %%
BUSL=pd.read_csv('BUSLOANS.csv',parse_dates=['DATE'],index_col='DATE')
BUSL.head()
# Out:
#             BUSLOANS
# DATE
# 1947-01-01   11.2894
# 1947-02-01   11.5179
# 1947-03-01   11.7667
# 1947-04-01   12.0269
# 1947-05-01   12.2788

# %%
BUSL_MON=BUSL['2000':].resample('M').mean()
BUSL_MON.head()
# Out:
#              BUSLOANS
# DATE
# 2000-01-31  1003.6327
# 2000-02-29  1016.5879
# 2000-03-31  1026.3008
# 2000-04-30  1035.2000
# 2000-05-31  1052.0774

# %%
BUSL_MON=BUSL_MON.shift(-1)
BUSL_MON.dropna(axis=0,inplace=True)
BUSL_MON.head()
# Out:
#              BUSLOANS
# DATE
# 2000-01-31  1016.5879
# 2000-02-29  1026.3008
# 2000-03-31  1035.2000
# 2000-04-30  1052.0774
# 2000-05-31  1062.8140

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(BUSL_MON,'b',label='BUSL')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Billions of U.S. Dollars',
       title='Commercial and Industrial Loans, All Commercial Banks ')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Comercial_Industrial_Loans.png',bbox_inches='tight')

# %%
BUSL_log=np.log(BUSL_MON)
BUSL_log.head()
# Out:
#             BUSLOANS
# DATE
# 2000-01-31  6.924207
# 2000-02-29  6.933716
# 2000-03-31  6.942350
# 2000-04-30  6.958522
# 2000-05-31  6.968675

# %% [markdown]
# ### Delinquency Rate on Credit Card Loans, All Commercial Banks

# %%
DRC=pd.read_csv('DRCCLACBS.csv',parse_dates=['DATE'],index_col='DATE')
DRC.head()
# Out:
#             DRCCLACBS
# DATE
# 1991-01-01       5.26
# 1991-04-01       5.48
# 1991-07-01       5.35
# 1991-10-01       5.32
# 1992-01-01       5.27

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(DRC,'b',label='DRC')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Quarters)', ylabel='Percent, Seasonally Adjusted',
       title='Delinquency Rate on Credit Card Loans, All Commercial Banks ')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Delinquency_Rate_Credit_CardLoans.png',bbox_inches='tight')

# %% [markdown]
# ### Delinquency Rate on All Loans, All Commercial Banks

# %%
DRA=pd.read_csv('DRALACBS.csv',parse_dates=['DATE'],index_col='DATE')
DRA.head()
# Out:
#             DRALACBS
# DATE
# 1985-01-01      4.61
# 1985-04-01      4.92
# 1985-07-01      4.91
# 1985-10-01      4.77
# 1986-01-01      4.85

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(DRA['2000':],'b',label='DRA')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Quarters)', ylabel='Percent, Seasonally Adjusted',
       title='Delinquency Rate on All Loans, All Commercial Banks ')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Delinquency_Rate_Credit_CardLoans.png',bbox_inches='tight')

# %% [markdown]
# ## Stock Index
#
# ### S&P 500 Index

# %%
GSPC=pd.read_csv('^GSPC.csv',parse_dates=['Date'],index_col='Date')
GSPC.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1927-12-30  17.660000  17.660000  17.660000  17.660000  17.660000       0
# 1928-01-03  17.760000  17.760000  17.760000  17.760000  17.760000       0
# 1928-01-04  17.719999  17.719999  17.719999  17.719999  17.719999       0
# 1928-01-05  17.549999  17.549999  17.549999  17.549999  17.549999       0
# 1928-01-06  17.660000  17.660000  17.660000  17.660000  17.660000       0

# %%
GSPC.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-03-02  2974.280029  3090.959961  2945.189941  3090.229980  3090.229980
# 2020-03-03  3096.459961  3136.719971  2976.629883  3003.370117  3003.370117
# 2020-03-04  3045.750000  3130.969971  3034.379883  3130.120117  3130.120117
# 2020-03-05  3075.699951  3083.040039  2999.830078  3023.939941  3023.939941
# 2020-03-06  2954.199951  2985.929932  2901.540039  2972.370117  2972.370117
#
#                 Volume
# Date
# 2020-03-02  6376400000
# 2020-03-03  6355940000
# 2020-03-04  5035480000
# 2020-03-05  5575550000
# 2020-03-06  6552140000

# %%
GSPC_MON=GSPC['Close']['2000':'2020-02'].resample('M').mean()
# rename the column of the newly created series
GSPC_MON.rename('SP500', inplace=True)
GSPC_MON.head()
# Out:
# Date
# 2000-01-31    1425.585504
# 2000-02-29    1388.874500
# 2000-03-31    1442.212599
# 2000-04-30    1461.355257
# 2000-05-31    1418.479548
# Freq: M, Name: SP500, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(GSPC_MON,'b',label='GSPC')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Index Value',
       title='S&P 500 Adj Close Monthly Average')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\SP_500_Mon_Avg.png',bbox_inches='tight')

# %%
GSPC_log=np.log(GSPC_MON)
GSPC_log.head()
# Out:
# Date
# 2000-01-31    7.262338
# 2000-02-29    7.236249
# 2000-03-31    7.273934
# 2000-04-30    7.287120
# 2000-05-31    7.257341
# Freq: M, Name: SP500, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(GSPC_log,'b',label='GSPC')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Log Index Value',
       title='Log S&P 500 Adj Close Index')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\SP_500_Norm.png',bbox_inches='tight')

# %% [markdown]
# ### VIX Index

# %%
VIX=pd.read_csv('^VIX.csv',parse_dates=['Date'],index_col='Date')
VIX.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1990-01-02  17.240000  17.240000  17.240000  17.240000  17.240000       0
# 1990-01-03  18.190001  18.190001  18.190001  18.190001  18.190001       0
# 1990-01-04  19.219999  19.219999  19.219999  19.219999  19.219999       0
# 1990-01-05  20.110001  20.110001  20.110001  20.110001  20.110001       0
# 1990-01-08  20.260000  20.260000  20.260000  20.260000  20.260000       0

# %%
VIX_MON=VIX['Close']['2000':'2020-02'].resample('M').mean()/100
# rename the column of the newly created series
VIX_MON.rename('VIX', inplace=True)
VIX_MON.head()
# Out:
# Date
# 2000-01-31    0.232020
# 2000-02-29    0.235955
# 2000-03-31    0.227183
# 2000-04-30    0.271642
# 2000-05-31    0.263732
# Freq: M, Name: VIX, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(VIX_MON,'b',label='VIX')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Percent',
       title='VIX Monthly Average')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\VIX_Mon_Avg.png',bbox_inches='tight')

# %% [markdown]
# ## Macroeconomic Index
#
# ### US Policy Uncertainty Data

# %%
USP=pd.read_excel('US_Policy_Uncertainty_Data.xlsx','Main Index')
USP.head()
# Out:
#    Year  Month  Day  Three_Component_Index  News_Based_Policy_Uncert_Index
# 0  1985      1    1             125.224739                      103.748802
# 1  1985      2    1              99.020813                       78.313202
# 2  1985      3    1             112.190506                      100.761482
# 3  1985      4    1             102.811325                       84.778870
# 4  1985      5    1             120.082726                       98.053658

# %%
type(USP.Year[1])
# Out:
# numpy.int64

# %%
USP['Date']=pd.to_datetime(USP[['Year','Month','Day']])
USP.head()
# Out:
#    Year  Month  Day  Three_Component_Index  News_Based_Policy_Uncert_Index  \
# 0  1985      1    1             125.224739                      103.748802
# 1  1985      2    1              99.020813                       78.313202
# 2  1985      3    1             112.190506                      100.761482
# 3  1985      4    1             102.811325                       84.778870
# 4  1985      5    1             120.082726                       98.053658
#
#         Date
# 0 1985-01-01
# 1 1985-02-01
# 2 1985-03-01
# 3 1985-04-01
# 4 1985-05-01

# %%
USP.set_index('Date',inplace=True)
USP.head()
# Out:
#             Year  Month  Day  Three_Component_Index  \
# Date
# 1985-01-01  1985      1    1             125.224739
# 1985-02-01  1985      2    1              99.020813
# 1985-03-01  1985      3    1             112.190506
# 1985-04-01  1985      4    1             102.811325
# 1985-05-01  1985      5    1             120.082726
#
#             News_Based_Policy_Uncert_Index
# Date
# 1985-01-01                      103.748802
# 1985-02-01                       78.313202
# 1985-03-01                      100.761482
# 1985-04-01                       84.778870
# 1985-05-01                       98.053658

# %%
USP.drop(columns=['Year','Month','Day'],axis=1,inplace=True)
USP.head()
# Out:
#             Three_Component_Index  News_Based_Policy_Uncert_Index
# Date
# 1985-01-01             125.224739                      103.748802
# 1985-02-01              99.020813                       78.313202
# 1985-03-01             112.190506                      100.761482
# 1985-04-01             102.811325                       84.778870
# 1985-05-01             120.082726                       98.053658

# %%
USP_MON=USP['Three_Component_Index']['2000':].resample('M').mean()/100
# rename the column of the newly created series
USP_MON.rename('USPUI', inplace=True)
USP_MON.head()
# Out:
# Date
# 2000-01-31    0.892015
# 2000-02-29    0.776014
# 2000-03-31    0.775483
# 2000-04-30    0.760592
# 2000-05-31    0.979862
# Freq: M, Name: USPUI, dtype: float64

# %%
f, ax = plt.subplots(figsize = (15,5))
ax.plot(USP_MON,'b',label='USP')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Index Value',
       title='US Uncertainty  Monthly Index')
#introduce grid on the plot
ax.grid()
#Save the plot
f.savefig('USP_Mon.png',bbox_inches='tight')

# %%
USP_log=(USP_MON)
USP_log.head()
# Out:
# Date
# 2000-01-31    0.892015
# 2000-02-29    0.776014
# 2000-03-31    0.775483
# 2000-04-30    0.760592
# 2000-05-31    0.979862
# Freq: M, Name: USPUI, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(USP_log,'b',label='USP')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Index Value',
       title='US Uncertainty  Monthly Index Normalised')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('USP_Mon_Norm.png',bbox_inches='tight')

# %% [markdown]
# ### Industrial Production Index

# %%
INDPRO=pd.read_csv('INDPRO.csv',parse_dates=['DATE'],index_col='DATE')
INDPRO=INDPRO/100
INDPRO.head()
# Out:
#               INDPRO
# DATE
# 1919-01-01  0.050124
# 1919-02-01  0.047908
# 1919-03-01  0.046524
# 1919-04-01  0.047355
# 1919-05-01  0.047632

# %%
INDPRO.tail()
# Out:
#               INDPRO
# DATE
# 2019-10-01  1.090103
# 2019-11-01  1.100260
# 2019-12-01  1.095587
# 2020-01-01  1.089993
# 2020-02-01  1.096035

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(INDPRO['2000':],'b',label='INDPRO')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='INDEX 2012=100',
       title='Idustrial Production Index')
#introduce grid on the plot
ax.grid()

# %%
INDPRO_MON=INDPRO['2000':'2020-02'].resample('M').mean()/100
# rename the column of the newly created series
INDPRO_MON.head()
# Out:
#               INDPRO
# DATE
# 2000-01-31  0.009418
# 2000-02-29  0.009446
# 2000-03-31  0.009480
# 2000-04-30  0.009548
# 2000-05-31  0.009564

# %%
INDPRO_MON=INDPRO_MON.shift(-1)
INDPRO_MON.dropna(axis=0,inplace=True)
INDPRO_MON.head()
# Out:
#               INDPRO
# DATE
# 2000-01-31  0.009446
# 2000-02-29  0.009480
# 2000-03-31  0.009548
# 2000-04-30  0.009564
# 2000-05-31  0.009574

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(INDPRO_MON,'b',label='INDPRO')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Index 2012=100',
       title='Industrial Production Index')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\IndPro.png',bbox_inches='tight')

# %%
INDPRO_log=(INDPRO_MON)
INDPRO_log.head()
# Out:
#               INDPRO
# DATE
# 2000-01-31  0.009446
# 2000-02-29  0.009480
# 2000-03-31  0.009548
# 2000-04-30  0.009564
# 2000-05-31  0.009574

# %% [markdown]
# ### Producer Price Index for All Commodities

# %%
PPIACO=pd.read_csv('PPIACO.csv',parse_dates=['DATE'],index_col='DATE')
PPIACO.head()
# Out:
#             PPIACO
# DATE
# 1913-01-01    12.1
# 1913-02-01    12.0
# 1913-03-01    12.0
# 1913-04-01    12.0
# 1913-05-01    11.9

# %%
PPIACO_MON=PPIACO['2000':].resample('M').mean()/100
PPIACO_MON.head()
# Out:
#             PPIACO
# DATE
# 2000-01-31   1.283
# 2000-02-29   1.298
# 2000-03-31   1.308
# 2000-04-30   1.307
# 2000-05-31   1.316

# %%
PPIACO_MON=PPIACO_MON.shift(-1)
PPIACO_MON.dropna(axis=0,inplace=True)
PPIACO_MON.head()
# Out:
#             PPIACO
# DATE
# 2000-01-31   1.298
# 2000-02-29   1.308
# 2000-03-31   1.307
# 2000-04-30   1.316
# 2000-05-31   1.338

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(PPIACO_MON,'b',label='PPIACO')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Index 1982=100',
       title='Producer Price Index for All Commodities')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Producer_Price.png',bbox_inches='tight')

# %% [markdown]
# ### Unemployment Rate

# %%
UNRATE=pd.read_csv('UNRATE.csv',parse_dates=['DATE'],index_col='DATE')
UNRATE.head()
# Out:
#             UNRATE
# DATE
# 1948-01-01     3.4
# 1948-02-01     3.8
# 1948-03-01     4.0
# 1948-04-01     3.9
# 1948-05-01     3.5

# %%
UNRATE_MON=UNRATE['2000':].resample('M').mean()
UNRATE_MON.head()
# Out:
#             UNRATE
# DATE
# 2000-01-31     4.0
# 2000-02-29     4.1
# 2000-03-31     4.0
# 2000-04-30     3.8
# 2000-05-31     4.0

# %%
UNRATE_MON=UNRATE_MON.shift(-1)
UNRATE_MON.dropna(axis=0,inplace=True)
UNRATE_MON.head()
# Out:
#             UNRATE
# DATE
# 2000-01-31     4.1
# 2000-02-29     4.0
# 2000-03-31     3.8
# 2000-04-30     4.0
# 2000-05-31     4.0

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(UNRATE_MON,'b',label='UNRATE')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='Percent',
       title='Unemployment Rate')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('UnemploymentRate.png',bbox_inches='tight')

# %% [markdown]
# ### Consumer Sentiment

# %%
UMCSENT=pd.read_csv('UMCSENT.csv',parse_dates=['DATE'],index_col='DATE',na_values='.')
UMCSENT.head()
# Out:
#             UMCSENT
# DATE
# 1952-11-01     86.2
# 1952-12-01      NaN
# 1953-01-01      NaN
# 1953-02-01     90.7
# 1953-03-01      NaN

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(UMCSENT['2000':],'b',label='UNRATE')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='index 1966:Q1=100',
       title='Consumer Sentiment')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\ConsumerSentiment.png',bbox_inches='tight')

# %%
UMCSENT=UMCSENT.shift(-1)
UMCSENT=UMCSENT['2000' :]
UMCSENT_MON=UMCSENT.resample('M').mean()/100
UMCSENT_MON.head()
# Out:
#             UMCSENT
# DATE
# 2000-01-31    1.113
# 2000-02-29    1.071
# 2000-03-31    1.092
# 2000-04-30    1.107
# 2000-05-31    1.064

# %% [markdown]
# ## Other Indexes

# %% [markdown]
# ### Crude Oil Prices: West Texas Intermediate (WTI) - Cushing, Oklahoma

# %%
DCOIL=pd.read_csv('DCOILWTICO.csv',parse_dates=['DATE'],index_col='DATE')
DCOIL.head()
# Out:
#            DCOILWTICO
# DATE
# 1986-01-02      25.56
# 1986-01-03      26.00
# 1986-01-06      26.53
# 1986-01-07      25.85
# 1986-01-08      25.87

# %%
DCOIL.dtypes
# Out:
# DCOILWTICO    object
# dtype: object

# %%
DCOIL=pd.to_numeric(DCOIL['DCOILWTICO'], errors='coerce')
DCOIL.dtypes
# Out:
# dtype('float64')

# %%
DCOIL_MON=DCOIL['2000':].resample('M').mean()
DCOIL_MON.head()
# Out:
# DATE
# 2000-01-31    27.259474
# 2000-02-29    29.366000
# 2000-03-31    29.841739
# 2000-04-30    25.722105
# 2000-05-31    28.788182
# Freq: M, Name: DCOILWTICO, dtype: float64

# %%
DCOIL_MON=DCOIL_MON.shift(-1)
DCOIL_MON.dropna(axis=0,inplace=True)
DCOIL_MON.head()
# Out:
# DATE
# 2000-01-31    29.366000
# 2000-02-29    29.841739
# 2000-03-31    25.722105
# 2000-04-30    28.788182
# 2000-05-31    31.822273
# Freq: M, Name: DCOILWTICO, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(DCOIL_MON,'b',label='DCOIL')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='US $ per Barrel',
       title='Crude Oil Prices: West Texas Intermediate (WTI) - Cushing, Oklahoma')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('Graphs\Crude_Oil_Prices.png',bbox_inches='tight')

# %%
DCOIL_log=np.log(DCOIL_MON)
DCOIL_log.head()
# Out:
# DATE
# 2000-01-31    3.379838
# 2000-02-29    3.395908
# 2000-03-31    3.247351
# 2000-04-30    3.359965
# 2000-05-31    3.460166
# Freq: M, Name: DCOILWTICO, dtype: float64

# %% [markdown]
# ### U.S. / Euro Foreign Exchange Rate

# %%
USEU=pd.read_csv('DEXUSEU.csv',parse_dates=['DATE'],index_col='DATE')
USEU.head()
# Out:
#            DEXUSEU
# DATE
# 1999-01-04  1.1812
# 1999-01-05  1.1760
# 1999-01-06  1.1636
# 1999-01-07  1.1672
# 1999-01-08  1.1554

# %%
USEU.dtypes
# Out:
# DEXUSEU    object
# dtype: object

# %%
USEU=pd.to_numeric(USEU['DEXUSEU'],errors='coerce')
USEU.dtypes
# Out:
# dtype('float64')

# %%
USEU_MON=USEU['2000':].resample('M').mean()
USEU_MON.head()
# Out:
# DATE
# 2000-01-31    1.013110
# 2000-02-29    0.983360
# 2000-03-31    0.964339
# 2000-04-30    0.944920
# 2000-05-31    0.905945
# Freq: M, Name: DEXUSEU, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(USEU_MON,'b',label='USEU')
ax.axvspan('2007-12', '2009-06', color='grey', alpha=0.5)
# define the axes properties and the title of the graph
ax.set(xlabel='time (Month)', ylabel='US $ to One Euro',
       title='U.S. / Euro Foreign Exchange Rate')
#introduce grid on the plot
ax.grid()
#Save the plot
fig.savefig('US_Euro_Foreign_Exchange_Rate.png',bbox_inches='tight')

# %% [markdown]
# ## Cross Correlation

# %%
Money=pd.concat([MULT_MON,MZM_log,CPIL_MON,CSCICP_MON,EXCSR_log,WSAV_log,FED_MON,
                 TYM_MON,CONS_log,REL_log,BUSL_log,GSPC_log,VIX_MON,UMCSENT_MON,USP_MON,INDPRO_log,PPIACO_MON,UNRATE_MON,
                DCOIL_MON,USEU_MON],axis=1)
Money.head()
# Out:
#                 MULT       MZM  CPILFESL    CSCICP  EXCSRESNS    WSAVNS  \
# DATE
# 2000-01-31  1.826000  8.385781     1.794  1.026613   2.491551  7.456431
# 2000-02-29  1.842500  8.385705     1.800  1.025828   2.457021  7.463707
# 2000-03-31  1.842500  8.393635     1.803  1.025648   2.272126  7.478099
# 2000-04-30  1.856500  8.405798     1.807  1.025403   2.411439  7.495042
# 2000-05-31  1.829667  8.404150     1.811  1.024444   2.436241  7.478825
#
#             FEDFUNDS    T10Y3M  CONSUMER  RealEstLoans  BUSLOANS     SP500  \
# DATE
# 2000-01-31      5.73  0.011655  6.236030      4.666717  6.924207  7.262338
# 2000-02-29      5.85  0.007852  6.243544      4.685127  6.933716  7.236249
# 2000-03-31      6.02  0.003926  6.254418      4.710765  6.942350  7.273934
# 2000-04-30      6.27  0.001705  6.261456      4.730729  6.958522  7.287120
# 2000-05-31      6.53  0.004485  6.272001      4.739586  6.968675  7.257341
#
#                  VIX  UMCSENT     USPUI    INDPRO  PPIACO  UNRATE  DCOILWTICO  \
# DATE
# 2000-01-31  0.232020    1.113  0.892015  0.009446   1.298     4.1   29.366000
# 2000-02-29  0.235955    1.071  0.776014  0.009480   1.308     4.0   29.841739
# 2000-03-31  0.227183    1.092  0.775483  0.009548   1.307     3.8   25.722105
# 2000-04-30  0.271642    1.107  0.760592  0.009564   1.316     4.0   28.788182
# 2000-05-31  0.263732    1.064  0.979862  0.009574   1.338     4.0   31.822273
#
#              DEXUSEU
# DATE
# 2000-01-31  1.013110
# 2000-02-29  0.983360
# 2000-03-31  0.964339
# 2000-04-30  0.944920
# 2000-05-31  0.905945

# %%
Money.tail()
# Out:
#               MULT       MZM  CPILFESL    CSCICP  EXCSRESNS    WSAVNS  \
# DATE
# 2019-11-30  1.1975  9.734443   2.65832  1.013442   9.616184  9.187044
# 2019-12-31  1.1970  9.739427   2.66476  1.015018        NaN  9.189725
# 2020-01-31     NaN  9.747440       NaN  1.016414        NaN  9.200242
# 2020-02-29     NaN  9.752707       NaN       NaN        NaN  9.200025
# 2020-03-31     NaN       NaN       NaN       NaN        NaN       NaN
#
#             FEDFUNDS    T10Y3M  CONSUMER  RealEstLoans  BUSLOANS     SP500  \
# DATE
# 2019-11-30      1.55  0.002424  7.371015      5.771536  7.764619  8.040738
# 2019-12-31      1.55  0.002986  7.375162      5.763871  7.763517  8.063614
# 2020-01-31      1.58  0.002137  7.379804      5.755558  7.765635  8.095051
# 2020-02-29       NaN -0.000390       NaN      5.752220       NaN  8.094780
# 2020-03-31       NaN       NaN       NaN           NaN       NaN       NaN
#
#                  VIX  UMCSENT     USPUI    INDPRO  PPIACO  UNRATE  DCOILWTICO  \
# DATE
# 2019-11-30  0.125235    0.993  1.317507  0.010956   1.992     3.5   59.878182
# 2019-12-31  0.137567    0.998  1.434672  0.010900   1.994     3.6   57.683636
# 2020-01-31  0.139410    1.010  1.313958  0.010960   1.965     3.5   50.542632
# 2020-02-29  0.196289      NaN  1.558477       NaN     NaN     NaN   38.980000
# 2020-03-31       NaN      NaN       NaN       NaN     NaN     NaN         NaN
#
#              DEXUSEU
# DATE
# 2019-11-30  1.105058
# 2019-12-31  1.111367
# 2020-01-31  1.109767
# 2020-02-29  1.091074
# 2020-03-31  1.121790

# %% [markdown]
# The cross correlation of the selected variables from 2000 up to 2007 (with the year 2007)
#
# We will calculate this using the spearman correlation method as we do not now if ther is a linear relationship between all variables

# %%
Money['2000':'2007-12'].tail()
# Out:
#               MULT       MZM  CPILFESL    CSCICP  EXCSRESNS    WSAVNS  \
# DATE
# 2007-08-31  1.6000  8.954199   2.11554  0.995374   2.681022  8.252739
# 2007-09-30  1.6180  8.968816   2.12077  0.992503   2.829087  8.253540
# 2007-10-31  1.6085  8.982363   2.12660  0.989717   2.882004  8.247822
# 2007-11-30  1.6025  8.993803   2.13168  0.988078   2.802148  8.258817
# 2007-12-31  1.6170  9.003333   2.13771  0.986502   2.781920  8.258899
#
#             FEDFUNDS    T10Y3M  CONSUMER  RealEstLoans  BUSLOANS     SP500  \
# DATE
# 2007-08-31      4.94  0.003578  6.650803      6.156130  7.207896  7.282498
# 2007-09-30      4.76  0.005165  6.649818      6.166666  7.226062  7.311296
# 2007-10-31      4.49  0.005296  6.664925      6.176344  7.239733  7.339316
# 2007-11-30      4.24  0.007993  6.683280      6.183080  7.256801  7.288508
# 2007-12-31      3.94  0.010267  6.685285      6.189954  7.273140  7.299273
#
#                  VIX  UMCSENT     USPUI    INDPRO  PPIACO  UNRATE  DCOILWTICO  \
# DATE
# 2007-08-31  0.250261    0.834  0.891040  0.010516   1.735     4.7   79.914737
# 2007-09-30  0.221989    0.809  1.007444  0.010472   1.747     4.7   85.798696
# 2007-10-31  0.191157    0.761  0.894545  0.010533   1.790     4.7   94.772381
# 2007-11-30  0.255824    0.755  1.024411  0.010535   1.786     5.0   91.687000
# 2007-12-31  0.216510    0.784  1.085438  0.010506   1.810     5.0   92.970476
#
#              DEXUSEU
# DATE
# 2007-08-31  1.362587
# 2007-09-30  1.390985
# 2007-10-31  1.423304
# 2007-11-30  1.468252
# 2007-12-31  1.455880

# %%
Money_Cor=Money['2000':'2007-12'].corr(method='spearman')
Money_Cor
# Out:
#                   MULT       MZM  CPILFESL    CSCICP  EXCSRESNS    WSAVNS  \
# MULT          1.000000 -0.896069 -0.901721  0.660040  -0.543827 -0.898932
# MZM          -0.896069  1.000000  0.998152 -0.496785   0.562325  0.996961
# CPILFESL     -0.901721  0.998152  1.000000 -0.493714   0.564600  0.998077
# CSCICP        0.660040 -0.496785 -0.493714  1.000000  -0.457588 -0.493909
# EXCSRESNS    -0.543827  0.562325  0.564600 -0.457588   1.000000  0.561552
# WSAVNS       -0.898932  0.996961  0.998077 -0.493909   0.561552  1.000000
# FEDFUNDS     -0.019209  0.014828  0.015517  0.102938  -0.280873  0.012812
# T10Y3M        0.245274 -0.232990 -0.235483  0.064921   0.068314 -0.231498
# CONSUMER     -0.895303  0.995781  0.997229 -0.489799   0.569935  0.995795
# RealEstLoans -0.899149  0.995944  0.997786 -0.482976   0.559911  0.995402
# BUSLOANS     -0.344687  0.281755  0.283361 -0.300285  -0.149428  0.279164
# SP500        -0.148723  0.258193  0.260782  0.100122  -0.176951  0.259360
# VIX           0.450083 -0.679978 -0.682025 -0.066875  -0.347452 -0.682827
# UMCSENT       0.614417 -0.466842 -0.465053  0.950438  -0.411672 -0.465987
# USPUI         0.329406 -0.475570 -0.482862 -0.133370  -0.071048 -0.478839
# INDPRO       -0.689504  0.827496  0.831668 -0.190600   0.335793  0.829544
# PPIACO       -0.786838  0.921960  0.924539 -0.390910   0.476590  0.923669
# UNRATE       -0.086144  0.022747  0.017431 -0.234322   0.317893  0.020064
# DCOILWTICO   -0.744959  0.868801  0.873950 -0.347979   0.458545  0.872816
# DEXUSEU      -0.761210  0.898087  0.901758 -0.296975   0.499064  0.899878
#
#               FEDFUNDS    T10Y3M  CONSUMER  RealEstLoans  BUSLOANS     SP500  \
# MULT         -0.019209  0.245274 -0.895303     -0.899149 -0.344687 -0.148723
# MZM           0.014828 -0.232990  0.995781      0.995944  0.281755  0.258193
# CPILFESL      0.015517 -0.235483  0.997229      0.997786  0.283361  0.260782
# CSCICP        0.102938  0.064921 -0.489799     -0.482976 -0.300285  0.100122
# EXCSRESNS    -0.280873  0.068314  0.569935      0.559911 -0.149428 -0.176951
# WSAVNS        0.012812 -0.231498  0.995795      0.995402  0.279164  0.259360
# FEDFUNDS      1.000000 -0.909240  0.013219      0.014651  0.824672  0.876110
# T10Y3M       -0.909240  1.000000 -0.232664     -0.236883 -0.814094 -0.808804
# CONSUMER      0.013219 -0.232664  1.000000      0.995971  0.280562  0.261082
# RealEstLoans  0.014651 -0.236883  0.995971      1.000000  0.280955  0.255779
# BUSLOANS      0.824672 -0.814094  0.280562      0.280955  1.000000  0.806172
# SP500         0.876110 -0.808804  0.261082      0.255779  0.806172  1.000000
# VIX          -0.149647  0.287493 -0.685106     -0.689338 -0.084997 -0.331552
# UMCSENT       0.135655  0.036064 -0.458011     -0.452910 -0.254729  0.126602
# USPUI        -0.427944  0.474552 -0.486544     -0.483519 -0.305087 -0.535974
# INDPRO        0.438781 -0.572531  0.828174      0.828540  0.465193  0.641563
# PPIACO        0.227423 -0.444453  0.920101      0.919728  0.384283  0.451528
# UNRATE       -0.938544  0.864092  0.017550      0.016497 -0.731311 -0.872890
# DCOILWTICO    0.288592 -0.466848  0.873969      0.869452  0.372273  0.500665
# DEXUSEU       0.034840 -0.217363  0.900773      0.897911  0.161951  0.295998
#
#                    VIX   UMCSENT     USPUI    INDPRO    PPIACO    UNRATE  \
# MULT          0.450083  0.614417  0.329406 -0.689504 -0.786838 -0.086144
# MZM          -0.679978 -0.466842 -0.475570  0.827496  0.921960  0.022747
# CPILFESL     -0.682025 -0.465053 -0.482862  0.831668  0.924539  0.017431
# CSCICP       -0.066875  0.950438 -0.133370 -0.190600 -0.390910 -0.234322
# EXCSRESNS    -0.347452 -0.411672 -0.071048  0.335793  0.476590  0.317893
# WSAVNS       -0.682827 -0.465987 -0.478839  0.829544  0.923669  0.020064
# FEDFUNDS     -0.149647  0.135655 -0.427944  0.438781  0.227423 -0.938544
# T10Y3M        0.287493  0.036064  0.474552 -0.572531 -0.444453  0.864092
# CONSUMER     -0.685106 -0.458011 -0.486544  0.828174  0.920101  0.017550
# RealEstLoans -0.689338 -0.452910 -0.483519  0.828540  0.919728  0.016497
# BUSLOANS     -0.084997 -0.254729 -0.305087  0.465193  0.384283 -0.731311
# SP500        -0.331552  0.126602 -0.535974  0.641563  0.451528 -0.872890
# VIX           1.000000 -0.077006  0.789338 -0.691753 -0.690997  0.192421
# UMCSENT      -0.077006  1.000000 -0.157708 -0.171558 -0.372999 -0.247049
# USPUI         0.789338 -0.157708  1.000000 -0.658587 -0.518875  0.440753
# INDPRO       -0.691753 -0.171558 -0.658587  1.000000  0.913786 -0.434325
# PPIACO       -0.690997 -0.372999 -0.518875  0.913786  1.000000 -0.234636
# UNRATE        0.192421 -0.247049  0.440753 -0.434325 -0.234636  1.000000
# DCOILWTICO   -0.679829 -0.319634 -0.574376  0.941658  0.946751 -0.287032
# DEXUSEU      -0.635499 -0.297380 -0.480399  0.850570  0.877315 -0.034719
#
#               DCOILWTICO   DEXUSEU
# MULT           -0.744959 -0.761210
# MZM             0.868801  0.898087
# CPILFESL        0.873950  0.901758
# CSCICP         -0.347979 -0.296975
# EXCSRESNS       0.458545  0.499064
# WSAVNS          0.872816  0.899878
# FEDFUNDS        0.288592  0.034840
# T10Y3M         -0.466848 -0.217363
# CONSUMER        0.873969  0.900773
# RealEstLoans    0.869452  0.897911
# BUSLOANS        0.372273  0.161951
# SP500           0.500665  0.295998
# VIX            -0.679829 -0.635499
# UMCSENT        -0.319634 -0.297380
# USPUI          -0.574376 -0.480399
# INDPRO          0.941658  0.850570
# PPIACO          0.946751  0.877315
# UNRATE         -0.287032 -0.034719
# DCOILWTICO      1.000000  0.849132
# DEXUSEU         0.849132  1.000000

# %%
#define a mask to show only the values below the diagonal of the cross correlation matrix
mask = np.zeros_like(Money_Cor, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 18))
# create the heatmap
sns.heatmap(Money_Cor, cmap='cool', vmax=1,vmin=-1, center=0, annot=True,
            square=False, linewidths=.5, cbar_kws={"shrink": .5},mask=mask)
#define the place ofthe tickers in each axes
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
);
plt.title('Cross Correlation Matrix 2000-2007')
#set axis equal for better representation
plt.axis('equal')
# show
plt.show()
f.savefig('Graphs\Spearman_Corr_00-07.png',bbox_inches='tight')

# %% [markdown]
# The cross correlation of the selected variables from 2009-06 up to now

# %%
Money_Cor1=Money['2009-06':'2019'].corr(method='spearman')
Money_Cor1.head()
# Out:
#                MULT       MZM  CPILFESL    CSCICP  EXCSRESNS    WSAVNS  \
# MULT       1.000000  0.483927  0.472626  0.447401  -0.555601  0.470394
# MZM        0.483927  1.000000  0.996854  0.931841   0.370775  0.996157
# CPILFESL   0.472626  0.996854  1.000000  0.933797   0.371069  0.999274
# CSCICP     0.447401  0.931841  0.933797  1.000000   0.403441  0.933891
# EXCSRESNS -0.555601  0.370775  0.371069  0.403441   1.000000  0.371741
#
#            FEDFUNDS    T10Y3M  CONSUMER  RealEstLoans  BUSLOANS     SP500  \
# MULT       0.853296 -0.660649  0.494819     -0.473206  0.499529  0.454786
# MZM        0.676733 -0.851999  0.945292     -0.996942  0.990204  0.985582
# CPILFESL   0.682707 -0.854337  0.959441     -0.999695  0.982606  0.988207
# CSCICP     0.669673 -0.764371  0.909396     -0.933692  0.927036  0.948620
# EXCSRESNS -0.289852 -0.049887  0.290061     -0.371177  0.352897  0.384123
#
#                 VIX   UMCSENT     USPUI    INDPRO    PPIACO    UNRATE  \
# MULT      -0.079160  0.435446  0.267452  0.291637 -0.169201 -0.475786
# MZM       -0.552831  0.908172 -0.376687  0.908125  0.116852 -0.995086
# CPILFESL  -0.555093  0.910463 -0.371497  0.911411  0.121050 -0.996419
# CSCICP    -0.611245  0.980937 -0.467584  0.869106  0.056794 -0.937669
# EXCSRESNS -0.521828  0.389025 -0.657305  0.469438  0.240389 -0.373163
#
#            DCOILWTICO   DEXUSEU
# MULT        -0.350349 -0.375190
# MZM         -0.595777 -0.755454
# CPILFESL    -0.593744 -0.768900
# CSCICP      -0.592238 -0.752754
# EXCSRESNS   -0.186778 -0.291339

# %%
#define a mask to show only the values below the diagonal of the cross correlation matrix
mask = np.zeros_like(Money_Cor1, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 18))
# create the heatmap
sns.heatmap(Money_Cor1, cmap='cool', vmax=1,vmin=-1, center=0, annot=True,
            square=False, linewidths=.5, cbar_kws={"shrink": .5}, mask=mask)
#define the place ofthe tickers in each axes
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
);
plt.title('Cross Correlation Matrix 2009-2020')
#set axis equal for better representation
plt.axis('equal')
# show
plt.show()
f.savefig('Graphs\Spearman_Corr_10-now.png',bbox_inches='tight')

# %% [markdown]
# ## Clustering

# %%
fig=sns.clustermap(Money['2000':'2007'], metric="correlation", method="single", cmap="Reds", standard_scale=1,linewidth=.1)
plt.title('Clustering 2000-2007')
plt.show()
fig.savefig('Graphs\ClusterMap_00_07.png',bbox_inches='tight')

# %%
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)
    
Money_t=(Money['2000':'2007']-Money['2000':'2007'].mean())/Money['2000':'2007'].std()
# normalize the variables for the clustering analysis
Money_t1=Money_t.transpose()
# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)
fig=plt.figure(figsize=(20,10))
model = model.fit(Money_t1)
plt.title('Hierarchical Clustering Dendrogram from 2000 to 2007 method="Ward", metric="Euclidean"',)
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level',labels=list(Money['2000':'2007'].columns))
plt.xlabel("Variable Names")
plt.xticks(rotation=45)
plt.axhline(linestyle='--', y=22,color='k',lw=5)
plt.show()
fig.savefig('Graphs\Hierarchical_00_07.png',bbox_inches='tight')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

linked = linkage(Money_t1, 'single','correlation')

labelList = list(Money['2000':'2007'].columns)

fig=plt.figure(figsize=(20, 7))
dendrogram(linked,
            orientation='top',
            labels=labelList,
            distance_sort='descending')
plt.title('Hierarchical Clustering 00-07, method="Single", metric="Correlation"')
plt.xticks(rotation=45)
plt.show()
fig.savefig('Graphs\Hierarchical_Clustering_00_07_Corr.png')

# %%
linked = linkage(Money_t1, 'complete','correlation')

labelList = list(Money['2000':'2007'].columns)

fig=plt.figure(figsize=(20, 7))
dendrogram(linked,
            orientation='top',
            labels=labelList,
            distance_sort='descending')
plt.title('Hierarchical Clustering 00-07, method="Complete", metric="Correlation"')
plt.xticks(rotation=45)
plt.show()
fig.savefig('Graphs\Hierarchical_Clustering_00_07_Corr_Comp.png')

# %%
fig=sns.clustermap(Money['2009-06':'2019-11'], metric="correlation", method="single", cmap="Reds", standard_scale=1,linewidth=.1)
plt.title('Clustering 2009-2020')
plt.show()
fig.savefig('Graphs\ClusterMap_10_19.png',bbox_inches='tight')

# %%
Money_t=(Money['2009-06':'2019-11']-Money['2009-06':'2019-11'].mean())/Money['2009-06':'2019-11'].std()
# normalize the variables for the cluster analysis
Money_t1=Money_t.transpose()
# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)
fig=plt.figure(figsize=(22,7))
model = model.fit(Money_t1)
plt.title('Hierarchical Clustering Dendrogram from 2009 to 2020')
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level',labels=list(Money['2009-06':'2019-11'].columns))
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.axhline(linestyle='--', y=22,color='k',lw=5)
plt.xticks(rotation=45)
plt.show()
fig.savefig('Graphs\Hierarchical_09_19.png',bbox_inches='tight')

# %%
linked = linkage(Money_t1, 'single','correlation')

labelList = list(Money['2009-06':'2019-11'].columns)

fig=plt.figure(figsize=(20, 7))
dendrogram(linked,
            orientation='top',
            labels=labelList,
            distance_sort='descending')
plt.title('Hierarchical Clustering 09-20, method="Single", metric="Correlation"')
plt.xticks(rotation=45)
plt.show()
fig.savefig('Graphs\Hierarchical_Clustering_09_20_Corr.png',bbbox_inches='tight')

# %%
linked = linkage(Money_t1, 'complete','correlation')

labelList = list(Money['2009-06':'2019-11'].columns)

fig=plt.figure(figsize=(20, 7))
dendrogram(linked,
            orientation='top',
            labels=labelList,
            distance_sort='descending')
plt.title('Hierarchical Clustering 09-20, method="Complete", metric="Correlation"')
plt.xticks(rotation=45)
plt.show()
fig.savefig('Graphs\Hierarchical_Clustering_09_20_Corr_Comp.png',bbbox_inches='tight')

# %% [markdown]
# ## PCA Analysis
#
# In order to go further in to our analysis with the VAR estimation model we must first redefine our variable set. We must exclude from our clustering analysis the standalone variables.

# %%
from sklearn.preprocessing import StandardScaler
print (Money['2009-06':'2019-11'].shape)
Money_St = StandardScaler().fit_transform(Money['2009-06':'2019-11'])
Money_St=pd.DataFrame(Money_St,columns=list(Money['2009-06':'2019-11'].columns),index=Money['2009-06':'2019-11'].index)
Money_new=Money_St.drop(columns=['SP500','CPILFESL','PPIACO'])
Money_new.head()
# Out:
# (126, 20)
#                 MULT       MZM    CSCICP  EXCSRESNS    WSAVNS  FEDFUNDS  \
# DATE
# 2009-06-30  0.440020 -1.468350 -1.483469  -2.671733 -2.131027 -0.576757
# 2009-07-31  0.941980 -1.464051 -1.450451  -2.295311 -2.091042 -0.576757
# 2009-08-31  0.788455 -1.475422 -1.316048  -1.823787 -2.075133 -0.590151
# 2009-09-30  0.375940 -1.488798 -1.293647  -1.565388 -1.989699 -0.630330
# 2009-10-31 -0.008540 -1.498298 -1.283043  -1.570848 -1.921691 -0.630330
#
#               T10Y3M  CONSUMER  RealEstLoans  BUSLOANS       VIX   UMCSENT  \
# DATE
# 2009-06-30  1.686476 -2.264619      1.491429 -0.842560  2.195141 -1.628214
# 2009-07-31  1.512617 -2.266257      1.476975 -0.942261  1.641382 -1.654301
# 2009-08-31  1.552831 -2.282094      1.455874 -1.024997  1.487850 -0.976045
# 2009-09-30  1.412041 -2.322971      1.440963 -1.122651  1.411515 -1.228217
# 2009-10-31  1.445752 -2.328359      1.477093 -1.181695  1.286100 -1.506476
#
#                USPUI    INDPRO    UNRATE  DCOILWTICO   DEXUSEU
# DATE
# 2009-06-30  0.040530 -2.644538  1.450618   -0.387246  1.310304
# 2009-07-31 -0.097611 -2.458821  1.497233   -0.063825  1.374552
# 2009-08-31  0.682525 -2.332036  1.590463   -0.140623  1.519850
# 2009-09-30  0.471491 -2.277998  1.683693    0.155341  1.776934
# 2009-10-31  0.254277 -2.210652  1.637078    0.262071  1.981666

# %%
# transpose the matrix in order to procide with the hierarchical clustering
Money_t1=Money_new.transpose()
# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)
fig=plt.figure(figsize=(20,8))
model = model.fit(Money_t1)
plt.title('Hierarchical Clustering Dendrogram from 2009 to 2020')
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level',labels=list(Money_new.columns))
plt.xlabel("Variable Names")
plt.axhline(linestyle='--', y=20,color='k',lw=5)
plt.xticks(rotation=45)
plt.show()
fig.savefig('Graphs\Hierarchical_New_09_19.png',bbox_inches='tight')

# %%
linked = linkage(Money_t1, 'complete','correlation')

labelList = list(Money_new.columns)

fig=plt.figure(figsize=(20, 7))
dendrogram(linked,
            orientation='top',
            labels=labelList,
            distance_sort='descending')
plt.title('Hierarchical Clustering 09-20 excluding SP500 and CPILFESL, method="Complete", metric="Correlation"')
plt.xticks(rotation=45)
plt.axhline(linestyle='--', y=0.5,color='k',lw=5)
plt.show()
fig.savefig('Graphs\Hierarchical_Clustering_09_20_Corr_Comp_Ex.png',bbbox_inches='tight')

# %%
Monetary1=Money_t[['VIX','USPUI']]
print(Monetary1.shape)
Monetary1.head()
# Out:
# (126, 2)
#                  VIX     USPUI
# DATE
# 2009-06-30  2.186413  0.040368
# 2009-07-31  1.634855 -0.097223
# 2009-08-31  1.481934  0.679811
# 2009-09-30  1.405903  0.469616
# 2009-10-31  1.280987  0.253266

# %%
from sklearn.decomposition import PCA
pca = PCA(0.90)
pca.fit(Monetary1)
PCA(copy=True, iterated_power='auto', n_components=0.90, random_state=None,
  svd_solver='auto', tol=0.0, whiten=False)
pca.n_components_
# Out:
# 2

# %%
pca_mon1 = PCA(n_components=1)
principalComponents_mon1 = pca_mon1.fit_transform(Monetary1)
principal_Df1 = pd.DataFrame(data = principalComponents_mon1
             , columns = ['Uncertainty'],index=Money['2009-06':'2019-11'].index)
principal_Df1.head()
# Out:
#             Uncertainty
# DATE
# 2009-06-30     1.574572
# 2009-07-31     1.087270
# 2009-08-31     1.528585
# 2009-09-30     1.326192
# 2009-10-31     1.084880

# %%
pca_mon1.explained_variance_ratio_
# Out:
# array([0.78258543])

# %%
np.sum(pca_mon1.explained_variance_ratio_)
# Out:
# 0.7825854305460561

# %%
Monetary2=Money_t[['DCOILWTICO','DEXUSEU']]
Monetary2.head()
# Out:
#             DCOILWTICO   DEXUSEU
# DATE
# 2009-06-30   -0.385706  1.305094
# 2009-07-31   -0.063571  1.369086
# 2009-08-31   -0.140064  1.513807
# 2009-09-30    0.154724  1.769869
# 2009-10-31    0.261029  1.973787

# %%
pca = PCA(0.85)
pca.fit(Monetary2)
PCA(copy=True, iterated_power='auto', n_components=0.90, random_state=None,
  svd_solver='auto', tol=0.0, whiten=False)
pca.n_components_
# Out:
# 1

# %%
pca_mon2 = PCA(n_components=1)
principalComponents_mon2 = pca_mon2.fit_transform(Monetary2)
principal_Df2 = pd.DataFrame(data = principalComponents_mon2
             , columns = ['International'],index=Money['2009-06':'2019-11'].index)
principal_Df2.head()
# Out:
#             International
# DATE
# 2009-06-30      -0.650105
# 2009-07-31      -0.923139
# 2009-08-31      -0.971382
# 2009-09-30      -1.360892
# 2009-10-31      -1.580254

# %%
pca_mon2.explained_variance_ratio_
# Out:
# array([0.90523608])

# %%
np.sum(pca_mon2.explained_variance_ratio_)
# Out:
# 0.905236082860158

# %%
Monetary3=Money_t[['T10Y3M','RealEstLoans','UNRATE']]
Monetary3.head()
# Out:
#               T10Y3M  RealEstLoans    UNRATE
# DATE
# 2009-06-30  1.679771      1.485498  1.444850
# 2009-07-31  1.506602      1.471103  1.491279
# 2009-08-31  1.546657      1.450085  1.584139
# 2009-09-30  1.406427      1.435234  1.676998
# 2009-10-31  1.440004      1.471220  1.630569

# %%
pca = PCA(0.85)
pca.fit(Monetary3)
PCA(copy=True, iterated_power='auto', n_components=0.90, random_state=None,
  svd_solver='auto', tol=0.0, whiten=False)
pca.n_components_
# Out:
# 1

# %%
pca_mon3 = PCA(n_components=1)
principalComponents_mon3 = pca_mon3.fit_transform(Monetary3)
principal_Df3 = pd.DataFrame(data = principalComponents_mon3
             , columns = ['MacroEco'],index=Money['2009-06':'2019-11'].index)
principal_Df3.head()
# Out:
#             MacroEco
# DATE
# 2009-06-30 -2.656575
# 2009-07-31 -2.578610
# 2009-08-31 -2.642393
# 2009-09-30 -2.609475
# 2009-10-31 -2.622549

# %%
pca_mon3.explained_variance_ratio_
# Out:
# array([0.92150188])

# %%
Monetary4=Money_t[['MULT','FEDFUNDS']]
Monetary4.head()
# Out:
#                 MULT  FEDFUNDS
# DATE
# 2009-06-30  0.438270 -0.574464
# 2009-07-31  0.938234 -0.574464
# 2009-08-31  0.785320 -0.587804
# 2009-09-30  0.374445 -0.627824
# 2009-10-31 -0.008506 -0.627824

# %%
pca = PCA(0.85)
pca.fit(Monetary4)
PCA(copy=True, iterated_power='auto', n_components=0.85, random_state=None,
  svd_solver='auto', tol=0.0, whiten=False)
pca.n_components_
# Out:
# 1

# %%
pca_mon4 = PCA(n_components=1)
principalComponents_mon4 = pca_mon4.fit_transform(Monetary4)
principal_Df4 = pd.DataFrame(data = principalComponents_mon4
             , columns = ['Monetary'],index=Money['2009-06':'2019-11'].index)
principal_Df4.head()
# Out:
#             Monetary
# DATE
# 2009-06-30 -0.096303
# 2009-07-31  0.257224
# 2009-08-31  0.139665
# 2009-09-30 -0.179166
# 2009-10-31 -0.449953

# %%
Monetary5=Money_t[['UMCSENT','WSAVNS','CSCICP','MZM','BUSLOANS','CONSUMER','INDPRO']]
Monetary5.head()
# Out:
#              UMCSENT    WSAVNS    CSCICP       MZM  BUSLOANS  CONSUMER  \
# DATE
# 2009-06-30 -1.621740 -2.122554 -1.477570 -1.462511 -0.839210 -2.255614
# 2009-07-31 -1.647723 -2.082727 -1.444684 -1.458230 -0.938514 -2.257246
# 2009-08-31 -0.972164 -2.066882 -1.310815 -1.469556 -1.020921 -2.273020
# 2009-09-30 -1.223333 -1.981788 -1.288504 -1.482879 -1.118187 -2.313734
# 2009-10-31 -1.500486 -1.914050 -1.277941 -1.492340 -1.176996 -2.319101
#
#               INDPRO
# DATE
# 2009-06-30 -2.634023
# 2009-07-31 -2.449044
# 2009-08-31 -2.322763
# 2009-09-30 -2.268940
# 2009-10-31 -2.201862

# %%
pca = PCA(0.85)
pca.fit(Monetary5)
PCA(copy=True, iterated_power='auto', n_components=0.85, random_state=None,
  svd_solver='auto', tol=0.0, whiten=False)
pca.n_components_
# Out:
# 1

# %%
pca_mon5 = PCA(n_components=1)
principalComponents_mon5 = pca_mon5.fit_transform(Monetary5)
principal_Df5 = pd.DataFrame(data = principalComponents_mon5
             , columns = ['Liquidity'],index=Money['2009-06':'2019-11'].index)
principal_Df5.head()
# Out:
#             Liquidity
# DATE
# 2009-06-30   4.665361
# 2009-07-31   4.617037
# 2009-08-31   4.304029
# 2009-09-30   4.394189
# 2009-10-31   4.471205

# %%
pca_mon5.explained_variance_ratio_
# Out:
# array([0.91899125])

# %% [markdown]
# # Vector Autoregression (VAR)
#
# Find the first differences of the time series

# %%
Moneyfd1=pd.concat([Money_St[['SP500','CPILFESL','EXCSRESNS']],principal_Df1,principal_Df2,principal_Df3,principal_Df4,principal_Df5],axis=1)
Moneyfd=Moneyfd1.diff()
Moneyfd.dropna(axis=0,inplace=True)
Moneyfd.head()
# Out:
#                SP500  CPILFESL  EXCSRESNS  Uncertainty  International  \
# DATE
# 2009-07-31  0.031644  0.016907   0.376422    -0.487302      -0.273033
# 2009-08-31  0.230688  0.030767   0.471524     0.441315      -0.048244
# 2009-09-30  0.102920  0.042160   0.258398    -0.202393      -0.389510
# 2009-10-31  0.066419  0.011973  -0.005459    -0.241312      -0.219361
# 2009-11-30  0.057459  0.015601  -0.089878    -0.520907       0.065696
#
#             MacroEco  Monetary  Liquidity
# DATE
# 2009-07-31  0.077964  0.353528  -0.048324
# 2009-08-31 -0.063782 -0.117560  -0.313008
# 2009-09-30  0.032918 -0.318830   0.090160
# 2009-10-31 -0.013074 -0.270787   0.077015
# 2009-11-30 -0.005613 -0.200270  -0.211816

# %% [markdown]
# ## Visualize the Time Series

# %%
#Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    
        data = Moneyfd[Moneyfd.columns[i]]
        ax.plot(data, color='red', linewidth=1)
        # Decorations
        ax.set_title(Moneyfd.columns[i])
        ax.xaxis.set_ticks_position('none')
        ax.yaxis.set_ticks_position('none')
        ax.spines["top"].set_alpha(0)
        ax.tick_params(labelsize=6)
    
    
plt.tight_layout();
fig.savefig('Graphs\First_diff_Subplot.png',bbox_inches='tight')

# %% [markdown]
# ## Testing Causation using Granger’s Causality Test

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=1
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

MoneyGC1=grangers_causation_matrix(Moneyfd, variables = Moneyfd.columns) 
MoneyGC1
# Out:
#                  SP500_x  CPILFESL_x  EXCSRESNS_x  Uncertainty_x  \
# SP500_y           1.0000      0.3404       0.0050         0.3254
# CPILFESL_y        0.7828      1.0000       0.7916         0.3973
# EXCSRESNS_y       0.2645      0.3431       1.0000         0.4072
# Uncertainty_y     0.9162      0.3453       0.2258         1.0000
# International_y   0.4327      0.3858       0.1791         0.2419
# MacroEco_y        0.3431      0.8000       0.0021         0.1376
# Monetary_y        0.2031      0.5872       0.0002         0.7901
# Liquidity_y       0.6904      0.0474       0.2311         0.8996
#
#                  International_x  MacroEco_x  Monetary_x  Liquidity_x
# SP500_y                   0.0000      0.2007      0.0217       0.0072
# CPILFESL_y                0.9467      0.6209      0.0848       0.6180
# EXCSRESNS_y               0.9985      0.0176      0.5229       0.2254
# Uncertainty_y             0.0012      0.0304      0.0164       0.0030
# International_y           1.0000      0.7259      0.7574       0.0060
# MacroEco_y                0.0000      1.0000      0.0148       0.0074
# Monetary_y                0.1125      0.0713      1.0000       0.3207
# Liquidity_y               0.3290      0.9311      0.5631       1.0000

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 18))
# create the heatmap
cmap=sns.diverging_palette(10, 200, sep=20)
sns.heatmap(MoneyGC1, cmap=cmap, vmax=1,vmin=0, center=0.05, annot=True,
            square=False, linewidths=.5, cbar_kws={"shrink": .5})
#define the place ofthe tickers in each axes
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
);
plt.title('P-Value of Granger Causality with maxlag=1',)
#set axis equal for better representation
plt.axis('equal')
# show
plt.show()
f.savefig('Graphs\Granger_Causality_Matrix.png',bbox_inches='tight')

# %% [markdown]
# The row are the Response (Y) and the columns are the predictor series (X).
#
# For example, if you take the value 0.0003 in (row 1, column 2), it refers to the p-value of MULT_x causing GSPC_y. Whereas, the 0.000 in (row 2, column 1) refers to the p-value of MULT_y causing GSPC_x.
#
# So, how to interpret the p-values?
#
# If a given p-value is < significance level (0.05), then, the corresponding X series (column) causes the Y (row).
#
# For example, P-Value of 0.0003 at (row 1, column 2) represents the p-value of the Grangers Causality test for MULT_x causing GSPC_y, which is less that the significance level of 0.05.
#
# So, you can reject the null hypothesis and conclude MULT_x causes GSPC_y.
#
# Looking at the P-Values in the above table, you can pretty much observe that all the variables (time series) in the system are interchangeably causing each other.

# %% [markdown]
# ## Cointegration Test
#
# Cointegration test helps to establish the presence of a statistically significant connection between two or more time series.
#
# But, what does Cointegration mean?
#
# To understand that, you first need to know what is ‘order of integration’ (d).
#
# Order of integration(d) is nothing but the number of differencing required to make a non-stationary time series stationary.
#
# Now, when you have two or more time series, and there exists a linear combination of them that has an order of integration (d) less than that of the individual series, then the collection of series is said to be cointegrated.
#
# Ok?
#
# When two or more time series are cointegrated, it means they have a long run, statistically significant relationship.
#
# This is the basic premise on which Vector Autoregression(VAR) models is based on. So, it’s fairly common to implement the cointegration test before starting to build VAR models.
#
# Alright, So how to do this test?
#
# Soren Johanssen in his paper (1991) devised a procedure to implement the cointegration test.

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,1,1)
    d = {'0.9':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 10): return str(val).ljust(length)

    # Summary
    print('Johansen Cointegratgion test for linear trend')
    print('Name       ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

cointegration_test(Moneyfd)
# Out:
# Johansen Cointegratgion test for linear trend
# Name       ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# SP500      ::  544.26    > 175.1584  =>   True
# CPILFESL   ::  373.43    > 139.278   =>   True
# EXCSRESNS  ::  274.33    > 107.3429  =>   True
# Uncertainty ::  202.25    > 79.3422   =>   True
# International ::  137.85    > 55.2459   =>   True
# MacroEco   ::  92.73     > 35.0116   =>   True
# Monetary   ::  51.84     > 18.3985   =>   True
# Liquidity  ::  19.09     > 3.8415    =>   True

# %%
 def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,1)
    d = {'0.9':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 10): return str(val).ljust(length)

    # Summary
    print('Johansen Cointegratgion test for no deterministic terms')
    print('Name       ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

cointegration_test(Moneyfd)
# Out:
# Johansen Cointegratgion test for no deterministic terms
# Name       ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# SP500      ::  489.56    > 143.6691  =>   True
# CPILFESL   ::  327.13    > 111.7797  =>   True
# EXCSRESNS  ::  232.81    > 83.9383   =>   True
# Uncertainty ::  162.59    > 60.0627   =>   True
# International ::  101.17    > 40.1749   =>   True
# MacroEco   ::  59.77     > 24.2761   =>   True
# Monetary   ::  24.48     > 12.3212   =>   True
# Liquidity  ::  2.01      > 4.1296    =>   False

# %% [markdown]
# ## Check for Stationarity and Make the Time Series Stationary
#
# First, we implement a nice function (adfuller_test()) that writes out the results of the ADF test for any given time series and implement this function on each series one-by-one.

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
for name, column in Moneyfd.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "SP500"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -9.911
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.484
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CPILFESL"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.3364
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.484
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "EXCSRESNS"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.9851
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.485
#  Critical value 5%     = -2.886
#  Critical value 10%    = -2.58
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Uncertainty"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.517
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.488
#  Critical value 5%     = -2.887
#  Critical value 10%    = -2.58
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "International"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.3523
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.486
#  Critical value 5%     = -2.886
#  Critical value 10%    = -2.58
#  => P-Value = 0.0004. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "MacroEco"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -9.249
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.484
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Monetary"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.6453
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.484
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Liquidity"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.3234
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.485
#  Critical value 5%     = -2.886
#  Critical value 10%    = -2.58
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# ## How to Select the Order (P) of VAR model
#
# To select the right order of the VAR model, we iteratively fit increasing orders of VAR model and pick the order that gives a model with least AIC.
#
# Though the usual practice is to look at the AIC, you can also check other best fit comparison estimates of BIC, FPE and HQIC.

# %%
model = VAR(Moneyfd)
AICC=[0]*10
BICC=[0]*10
FPEE=[0]*10
HQICC=[0]*10
for i in [1,2,3,4,5,6,7,8,9]:
    result = model.fit(i)
    print('Lag Order =', i)
    AICC[i]=result.aic
    print('AIC : ', result.aic)
    BICC[i]=result.bic
    print('BIC : ', result.bic)
    FPEE[i]=result.fpe
    print('FPE : ', result.fpe)
    HQICC[i]=result.hqic
    print('HQIC: ', result.hqic, '\n')
# Out:
# Lag Order = 1
# AIC :  -35.01020368097106
# BIC :  -33.3726208364262
# FPE :  6.253888831043576e-16
# HQIC:  -34.34497902521456
#
# Lag Order = 2
# AIC :  -35.55574024453792
# BIC :  -32.44633315241882
# FPE :  3.6688041252086136e-16
# HQIC:  -34.29270689787512
#
# Lag Order = 3
# AIC :  -35.317553390107236
# BIC :  -30.720797579069114
# FPE :  4.810939750746517e-16
# HQIC:  -33.4504934396908
#
# Lag Order = 4
# AIC :  -34.89154719887833
# BIC :  -28.791640553939978
# FPE :  7.87036333830212e-16
# HQIC:  -32.414142558222466
#
# Lag Order = 5
# AIC :  -34.96915197360178
# BIC :  -27.350007876664193
# FPE :  8.175933891702324e-16
# HQIC:  -31.874982397580382
#
# Lag Order = 6
# AIC :  -34.938166436800266
# BIC :  -25.783406694785814
# FPE :  1.0162552651480707e-15
# HQIC:  -31.220707500018996
#
# Lag Order = 7
# AIC :  -34.95717889743668
# BIC :  -24.250126450349022
# FPE :  1.3285402939308494e-15
# HQIC:  -30.609799936169797
#
# Lag Order = 8
# AIC :  -35.10789058528076
# BIC :  -22.831561986179615
# FPE :  1.7578661675717144e-15
# HQIC:  -30.123852603283904
#
# Lag Order = 9
# AIC :  -35.64190438498049
# BIC :  -21.779002043548452
# FPE :  1.9587013705790454e-15
# HQIC:  -30.014357923626815

# %%
fig, ax = plt.subplots(ncols=2,nrows=2,figsize = (20,10))
ax[0,0].plot(AICC)
ax[0,1].plot(BICC)
ax[1,0].plot(FPEE)
ax[1,1].plot(HQICC)
# define the axes properties and the title of the graph
ax[0,0].set(xlabel='time (Lag)', ylabel='AIC Value',
       title='AIC Criterion')
ax[0,1].set(xlabel='time (Lag)', ylabel='BIC Value',
       title='BIC Criterion')
ax[1,0].set(xlabel='time (Lag)', ylabel='FPE Value x 10^{-13}',
       title='FPE Criterion')
ax[1,1].set(xlabel='time (Lag)', ylabel='HQIC Value',
       title='HQIC Criterion')
#introduce grid on the plot
ax[0,0].grid()
ax[0,1].grid()
ax[1,0].grid()
ax[1,1].grid()
#Save the plot
fig.savefig('Graphs\AIC_BIC_Critiria.png',bbox_inches='tight')

# %% [markdown]
# In the above output, the AIC drops to lowest at lag 3, then increases at lag 3 and then continuously drops further.
#
# Let’s go with the lag 3 model.

# %% [markdown]
# ## VAR Model of Selected Order(p)

# %%
model_fitted = model.fit(1)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 24, Apr, 2020
# Time:                     15:12:21
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                   -33.3726
# Nobs:                     124.000    HQIC:                  -34.3450
# Log likelihood:           835.046    FPE:                6.25389e-16
# AIC:                     -35.0102    Det(Omega_mle):     3.57035e-16
# --------------------------------------------------------------------
# Results for equation SP500
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.028717         0.019003            1.511           0.131
# L1.SP500                -0.102669         0.118408           -0.867           0.386
# L1.CPILFESL             -0.408312         0.585786           -0.697           0.486
# L1.EXCSRESNS             0.138865         0.051457            2.699           0.007
# L1.Uncertainty          -0.016889         0.011009           -1.534           0.125
# L1.International        -0.112140         0.029494           -3.802           0.000
# L1.MacroEco              0.144472         0.079994            1.806           0.071
# L1.Monetary             -0.072495         0.049013           -1.479           0.139
# L1.Liquidity            -0.131051         0.042939           -3.052           0.002
# ===================================================================================
#
# Results for equation CPILFESL
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.016329         0.002811            5.808           0.000
# L1.SP500                 0.025891         0.017517            1.478           0.139
# L1.CPILFESL              0.365827         0.086659            4.221           0.000
# L1.EXCSRESNS            -0.002097         0.007612           -0.275           0.783
# L1.Uncertainty           0.002163         0.001629            1.328           0.184
# L1.International        -0.002215         0.004363           -0.508           0.612
# L1.MacroEco              0.006443         0.011834            0.544           0.586
# L1.Monetary              0.013047         0.007251            1.799           0.072
# L1.Liquidity             0.005062         0.006352            0.797           0.426
# ===================================================================================
#
# Results for equation EXCSRESNS
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.039849         0.031423            1.268           0.205
# L1.SP500                -0.054393         0.195796           -0.278           0.781
# L1.CPILFESL             -0.779649         0.968636           -0.805           0.421
# L1.EXCSRESNS             0.362829         0.085087            4.264           0.000
# L1.Uncertainty           0.001661         0.018205            0.091           0.927
# L1.International         0.004696         0.048770            0.096           0.923
# L1.MacroEco             -0.286875         0.132275           -2.169           0.030
# L1.Monetary             -0.036839         0.081046           -0.455           0.649
# L1.Liquidity            -0.073549         0.071003           -1.036           0.300
# ===================================================================================
#
# Results for equation Uncertainty
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.053331         0.191033            0.279           0.780
# L1.SP500                 0.673257         1.190315            0.566           0.572
# L1.CPILFESL              2.552341         5.888688            0.433           0.665
# L1.EXCSRESNS            -0.535665         0.517274           -1.036           0.300
# L1.Uncertainty          -0.092218         0.110673           -0.833           0.405
# L1.International         0.857908         0.296488            2.894           0.004
# L1.MacroEco             -1.974074         0.804149           -2.455           0.014
# L1.Monetary              1.027328         0.492707            2.085           0.037
# L1.Liquidity             1.411133         0.431650            3.269           0.001
# ===================================================================================
#
# Results for equation International
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.034653         0.056445            0.614           0.539
# L1.SP500                -0.204343         0.351706           -0.581           0.561
# L1.CPILFESL             -1.097640         1.739951           -0.631           0.528
# L1.EXCSRESNS            -0.219639         0.152841           -1.437           0.151
# L1.Uncertainty           0.042048         0.032701            1.286           0.199
# L1.International         0.297888         0.087604            3.400           0.001
# L1.MacroEco             -0.162216         0.237605           -0.683           0.495
# L1.Monetary             -0.013764         0.145582           -0.095           0.925
# L1.Liquidity            -0.384501         0.127541           -3.015           0.003
# ===================================================================================
#
# Results for equation MacroEco
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.059286         0.022248            2.665           0.008
# L1.SP500                 0.186210         0.138629            1.343           0.179
# L1.CPILFESL             -0.516081         0.685819           -0.753           0.452
# L1.EXCSRESNS            -0.166225         0.060244           -2.759           0.006
# L1.Uncertainty           0.020346         0.012889            1.579           0.114
# L1.International         0.109612         0.034530            3.174           0.002
# L1.MacroEco              0.073218         0.093654            0.782           0.434
# L1.Monetary              0.099405         0.057382            1.732           0.083
# L1.Liquidity             0.157547         0.050272            3.134           0.002
# ===================================================================================
#
# Results for equation Monetary
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.012254         0.032357           -0.379           0.705
# L1.SP500                -0.119588         0.201614           -0.593           0.553
# L1.CPILFESL              0.798385         0.997418            0.800           0.423
# L1.EXCSRESNS            -0.261001         0.087615           -2.979           0.003
# L1.Uncertainty          -0.003856         0.018746           -0.206           0.837
# L1.International         0.053419         0.050219            1.064           0.287
# L1.MacroEco              0.108171         0.136206            0.794           0.427
# L1.Monetary              0.276275         0.083454            3.311           0.001
# L1.Liquidity            -0.097438         0.073112           -1.333           0.183
# ===================================================================================
#
# Results for equation Liquidity
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.127572         0.041461           -3.077           0.002
# L1.SP500                -0.160639         0.258344           -0.622           0.534
# L1.CPILFESL              2.669768         1.278069            2.089           0.037
# L1.EXCSRESNS             0.191150         0.112268            1.703           0.089
# L1.Uncertainty          -0.016474         0.024020           -0.686           0.493
# L1.International         0.087814         0.064349            1.365           0.172
# L1.MacroEco              0.014130         0.174531            0.081           0.935
# L1.Monetary              0.017715         0.106936            0.166           0.868
# L1.Liquidity             0.208593         0.093684            2.227           0.026
# ===================================================================================
#
# Correlation matrix of residuals
#                     SP500  CPILFESL  EXCSRESNS  Uncertainty  International  MacroEco  Monetary  Liquidity
# SP500            1.000000 -0.015964   0.051241    -0.608027      -0.068447 -0.336321  0.014062  -0.277352
# CPILFESL        -0.015964  1.000000   0.032208    -0.035059      -0.081772 -0.085492  0.089401   0.093456
# EXCSRESNS        0.051241  0.032208   1.000000     0.087437      -0.168393 -0.088923 -0.079024   0.008215
# Uncertainty     -0.608027 -0.035059   0.087437     1.000000       0.089893  0.266785  0.019442   0.191103
# International   -0.068447 -0.081772  -0.168393     0.089893       1.000000  0.008126  0.186805   0.061026
# MacroEco        -0.336321 -0.085492  -0.088923     0.266785       0.008126  1.000000 -0.062757   0.014477
# Monetary         0.014062  0.089401  -0.079024     0.019442       0.186805 -0.062757  1.000000  -0.066627
# Liquidity       -0.277352  0.093456   0.008215     0.191103       0.061026  0.014477 -0.066627   1.000000

# %%
# var model time series of order 1
model_fitted.plot()
plt.show()

# %%
irf=model_fitted.irf(20)

# %%
fig=irf.plot(orth=False,subplot_params={'fontsize':9})
plt.show()
fig.savefig('Graphs\ImpulseResponce.png')

# %%
fig1=irf.plot(orth=False,impulse='International',response='SP500',subplot_params={'fontsize':20})
fig1.savefig('Graphs\ImpulseResponse Int-SP500.png',bbox_inches='tight')

fig2=irf.plot(orth=False,impulse='International',response='MacroEco',subplot_params={'fontsize':20})
fig2.savefig('Graphs\ImpulseResponse Int-Macro.png',bbox_inches='tight')

fig3=irf.plot(orth=False,impulse='International',response='Uncertainty',subplot_params={'fontsize':20})
fig3.savefig('Graphs\ImpulseResponse Int-Unc.png',bbox_inches='tight')

fig4=irf.plot(orth=False,impulse='Liquidity',response='SP500',subplot_params={'fontsize':20})
fig4.savefig('Graphs\ImpulseResponse Liq-SP500.png',bbox_inches='tight')

fig5=irf.plot(orth=False,impulse='Liquidity',response='MacroEco',subplot_params={'fontsize':20})
fig5.savefig('Graphs\ImpulseResponse Liq-Macro.png',bbox_inches='tight')

fig6=irf.plot(orth=False,impulse='Liquidity',response='International',subplot_params={'fontsize':20})
fig6.savefig('Graphs\ImpulseResponse Liq-Int.png',bbox_inches='tight')

fig7=irf.plot(orth=False,impulse='Liquidity',response='Uncertainty',subplot_params={'fontsize':20})
fig7.savefig('Graphs\ImpulseResponse Liq-Unc.png',bbox_inches='tight')

fig8=irf.plot(orth=False,impulse='EXCSRESNS',response='MacroEco',subplot_params={'fontsize':20})
fig8.savefig('Graphs\ImpulseResponse EXSRES-Macro.png',bbox_inches='tight')

fig9=irf.plot(orth=False,impulse='EXCSRESNS',response='Monetary',subplot_params={'fontsize':20})
fig9.savefig('Graphs\ImpulseResponse EXSRES-Monet.png',bbox_inches='tight')

fig10=irf.plot(orth=False,impulse='EXCSRESNS',response='SP500',subplot_params={'fontsize':20})
fig10.savefig('Graphs\ImpulseResponse EXSRES-SP500.png',bbox_inches='tight')

fig11=irf.plot(orth=False,impulse='CPILFESL',response='Liquidity',subplot_params={'fontsize':20})
fig11.savefig('Graphs\ImpulseResponse CPI-Liq.png',bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Check for Serial Correlation of Residuals (Errors) using Durbin Watson Statistic
#
# A common way of checking for serial correlation of errors can be measured using the Durbin Watson’s Statistic.
#
# Durbin Watson Statistic - Formula
#
# $ DW=\frac{\sum_{t=2}^{T}(e_t-e_{t-1})^2)}{\sum_{t=1}^{T}(e_t^2)}$
#
# The value of this statistic can vary between 0 and 4. The closer it is to the value 2, then there is no significant serial correlation. The closer to 0, there is a positive serial correlation, and the closer it is to 4 implies negative serial correlation.

# %%
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(model_fitted.resid)

for col, val in zip(Moneyfd.columns, out):
    print(col, ':', round(val, 2))
# Out:
# SP500 : 1.91
# CPILFESL : 2.16
# EXCSRESNS : 2.07
# Uncertainty : 2.06
# International : 2.02
# MacroEco : 1.93
# Monetary : 2.29
# Liquidity : 1.96
